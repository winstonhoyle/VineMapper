# %%
import requests

# %%
import geopandas as gpd
import pandas as pd

# %% [markdown]
# ## Open GIS Data

# %%
states_gdf = gpd.read_file('data/cb_2018_us_state_500k/cb_2018_us_state_500k.shp')

# %% [markdown]
# ## Open and format 2020 Election Data

# %%
elelection_data_2020 = pd.read_excel('data/federalelections2020.xlsx', sheet_name=None)
# Out:
# /mnt/c/Users/Winston/Documents/GitHub/VineMapper/California_Republican_Pres_Turnout_2020_2024/.venv/lib/python3.11/site-packages/openpyxl/worksheet/header_footer.py:48: UserWarning: Cannot parse header or footer so it will be ignored
#   warn("""Cannot parse header or footer so it will be ignored""")
# /mnt/c/Users/Winston/Documents/GitHub/VineMapper/California_Republican_Pres_Turnout_2020_2024/.venv/lib/python3.11/site-packages/openpyxl/worksheet/header_footer.py:48: UserWarning: Cannot parse header or footer so it will be ignored
#   warn("""Cannot parse header or footer so it will be ignored""")

# %%
election_2020_df = elelection_data_2020['3. Table 2 Electoral & Pop Vote'][['2020 PRESIDENTIAL ELECTORAL AND POPULAR VOTE','Unnamed: 3', 'Unnamed: 4','Unnamed: 6']]
election_2020_df = election_2020_df.rename(columns={'2020 PRESIDENTIAL ELECTORAL AND POPULAR VOTE': "state",'Unnamed: 3	': "biden", 'Unnamed: 4': "trump",'Unnamed: 6':"total"})

# %%
election_2020_df
# Out:
#                                                 state         biden  \
# 0                                                 NaN           NaN
# 1                                               STATE  POPULAR VOTE
# 2                                                 NaN     Biden (D)
# 3                                                  AL        849624
# 4                                                  AK        153778
# 5                                                  AZ       1672143
# 6                                                  AR        423932
# 7                                                  CA      11110639
# 8                                                  CO       1804352
# 9                                                  CT       1080831
# 10                                                 DE        296268
# 11                                                 DC        317323
# 12                                                 FL       5297045
# ...

# %% [markdown]
# ## Get 2024 Election data

# %%
election_data_url = 'https://static01.nyt.com/elections-assets/2020/data/api/2020-11-03/national-map-page/national/president.json'
