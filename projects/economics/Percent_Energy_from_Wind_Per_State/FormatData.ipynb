# %%
import geopandas as gpd
import pandas as pd

# %% [markdown]
# ## Open State data

# %%
file_path = "data/cb_2018_us_state_500k/cb_2018_us_state_500k.shp"
states_gdf = gpd.read_file(file_path)
states_gdf["NAME"] = states_gdf["NAME"].str.title()
states_gdf = states_gdf[["geometry", "NAME"]]

# %% [markdown]
# ## Open Energy Data

# %%
state_total_energy_record_names = [
    f"{state_name} : all fuels (utility-scale)"
    for state_name in list(states_gdf["NAME"])
]

# %%
state_wind_energy_record_names = [
    f"{state_name.title()} : wind" for state_name in list(states_gdf["NAME"])
]

# %%
state_solar_energy_record_names = [
    f"{state_name.title()} : all solar" for state_name in list(states_gdf["NAME"])
]

# %%
energy_df = pd.read_csv("data/Net_generation_for_all_sectors.csv")

# %%
def format_wind_col(row) -> int:
    wind = row["2023"]
    if wind.isnumeric():
        return int(wind)
    else:
        print(row["description"], row["2023"])
        return 0

# %%
def format_solar_col(row) -> int:
    solar = row["2023"]
    if solar.isnumeric():
        return int(solar)
    else:
        print(row["description"], row["2023"])
        return 0

# %%
solar_df = energy_df[energy_df["description"].isin(state_solar_energy_record_names)]
solar_df["NAME"] = solar_df["description"].str.split(":").str[0]
solar_df["SOLAR"] = solar_df.apply(lambda row: format_solar_col(row), axis=1)
solar_df = solar_df[["NAME", "SOLAR"]].reset_index(drop=True)
# Out:
# /tmp/ipykernel_53768/2041535960.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   solar_df["NAME"] = solar_df["description"].str.split(":").str[0]
# /tmp/ipykernel_53768/2041535960.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   solar_df["SOLAR"] = solar_df.apply(lambda row: format_solar_col(row), axis=1)

# %%
total_df = energy_df[energy_df["description"].isin(state_total_energy_record_names)]
total_df["NAME"] = total_df["description"].str.split(":").str[0]
total_df["TOTAL"] = total_df["2023"].astype(int)
total_df = total_df[["NAME", "TOTAL"]].reset_index(drop=True)
# Out:
# /tmp/ipykernel_53768/492978815.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   total_df["NAME"] = total_df["description"].str.split(":").str[0]
# /tmp/ipykernel_53768/492978815.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   total_df["TOTAL"] = total_df["2023"].astype(int)

# %%
wind_df = energy_df[energy_df["description"].isin(state_wind_energy_record_names)]
wind_df["NAME"] = wind_df["description"].str.split(":").str[0]
wind_df["WIND"] = wind_df.apply(lambda row: format_wind_col(row), axis=1)
wind_df = wind_df[["NAME", "WIND"]].reset_index(drop=True)
# Out:
# District Of Columbia : wind --
# Florida : wind --
# Georgia : wind --
# South Carolina : wind --
# Alabama : wind --
# Kentucky : wind --
# Mississippi : wind --
# Arkansas : wind --
# Louisiana : wind --
# /tmp/ipykernel_53768/1693024662.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   wind_df["NAME"] = wind_df["description"].str.split(":").str[0]
# /tmp/ipykernel_53768/1693024662.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   wind_df["WIND"] = wind_df.apply(lambda row: format_wind_col(row), axis=1)

# %%
total_with_solar_df = total_df.merge(solar_df, on="NAME", how="inner")

# %%
total_with_solar_df["ALL"] = total_with_solar_df["TOTAL"] + total_with_solar_df["SOLAR"]

# %%
formatted_energy_df = wind_df.merge(total_with_solar_df, how="inner", on="NAME")

# %%
formatted_energy_df["percent"] = (
    formatted_energy_df["WIND"] / formatted_energy_df["ALL"]
).round(decimals=3) * 100

# %% [markdown]
# ## Merge Data

# %%
formatted_energy_df["NAME"] = formatted_energy_df["NAME"].str.strip()
states_gdf["NAME"] = states_gdf["NAME"].str.strip()

# %%
energy_per_state_gdf = states_gdf.merge(formatted_energy_df, on="NAME", how="inner")

# %%
energy_per_state_gdf.sort_values("percent", ascending=False)
# Out:
#                                              geometry                  NAME  \
# 31  POLYGON ((-96.6397 42.73707, -96.63589 42.741,...                  Iowa
# 13  POLYGON ((-104.05788 44.9976, -104.05078 44.99...          South Dakota
# 25  POLYGON ((-102.05174 40.00308, -101.9167 40.00...                Kansas
# 2   POLYGON ((-103.00256 36.52659, -103.00219 36.6...              Oklahoma
# 12  POLYGON ((-109.05017 31.48, -109.04984 31.4995...            New Mexico
# 46  POLYGON ((-104.04868 48.86378, -104.04865 48.8...          North Dakota
# 10  POLYGON ((-104.05342 41.17054, -104.05324 41.1...              Nebraska
# 20  POLYGON ((-109.06025 38.59933, -109.05954 38.7...              Colorado
# 49  MULTIPOLYGON (((-89.59206 47.96668, -89.59147 ...             Minnesota
# 14  MULTIPOLYGON (((-94.7183 29.72886, -94.71721 2...                 Texas
# 23  POLYGON ((-111.05456 45.00096, -111.04507 45.0...               Wyoming
# 38  MULTIPOLYGON (((-67.3558 44.64226, -67.35437 4...                 Maine
# 30  POLYGON ((-116.04914 48.50205, -116.04913 48.5...               Montana
# 45  MULTIPOLYGON (((-123.59892 46.25145, -123.5984...                Oregon
# 8   POLYGON ((-117.24267 44.39655, -117.23484 44.3...                 Idaho
# 28  POLYGON ((-91.51297 40.18106, -91.51107 40.188...              Illinois
# 29  POLYGON ((-73.43774 44.04501, -73.43199 44.063...               Vermont
# 19  POLYGON ((-95.77355 40.5782, -95.76853 40.5833...              Missouri
# 48  POLYGON ((-88.09776 37.90403, -88.09448 37.905...               Indiana
# 11  MULTIPOLYGON (((-122.57039 48.53785, -122.5686...            Washington
# 6   MULTIPOLYGON (((-83.19159 42.03537, -83.18993 ...              Michigan
# 39  MULTIPOLYGON (((-156.06076 19.73055, -156.0566...                Hawaii
# 15  MULTIPOLYGON (((-118.60442 33.47855, -118.5987...            California
# 4   POLYGON ((-82.6432 38.16909, -82.643 38.16956,...         West Virginia
# 24  MULTIPOLYGON (((-72.03683 41.24984, -72.03496 ...              New York
# 44  MULTIPOLYGON (((-86.95617 45.35549, -86.95463 ...             Wisconsin
# 33  MULTIPOLYGON (((-70.61702 42.97718, -70.61529 ...         New Hampshire
# 43  MULTIPOLYGON (((-82.73571 41.60336, -82.73392 ...                  Ohio
# 21  POLYGON ((-114.05296 37.59278, -114.05247 37.6...                  Utah
# 26  MULTIPOLYGON (((179.48246 51.98283, 179.48656 ...                Alaska
# 41  MULTIPOLYGON (((-71.28802 41.64558, -71.28647 ...          Rhode Island
# 18  POLYGON ((-80.51989 40.90666, -80.51909 40.921...          Pennsylvania
# 34  POLYGON ((-114.81629 32.50804, -114.81432 32.5...               Arizona
# 37  MULTIPOLYGON (((-76.05015 37.9869, -76.04998 3...              Maryland
# 7   MULTIPOLYGON (((-70.23405 41.28565, -70.22361 ...         Massachusetts
# 27  POLYGON ((-120.00574 39.22866, -120.00559 39.2...                Nevada
# 1   MULTIPOLYGON (((-75.72681 35.93584, -75.71827 ...        North Carolina
# 40  MULTIPOLYGON (((-75.56555 39.51485, -75.56174 ...              Delaware
# 16  MULTIPOLYGON (((-88.05338 30.50699, -88.05109 ...               Alabama
# 3   MULTIPOLYGON (((-75.74241 37.80835, -75.74151 ...              Virginia
# 0   MULTIPOLYGON (((-88.50297 30.21524, -88.49176 ...           Mississippi
# 5   MULTIPOLYGON (((-88.8677 29.86155, -88.86566 2...             Louisiana
# 9   MULTIPOLYGON (((-80.17628 25.52505, -80.17395 ...               Florida
# 17  MULTIPOLYGON (((-81.27939 31.30792, -81.27716 ...               Georgia
# 22  POLYGON ((-90.3103 35.0043, -90.30988 35.00975...             Tennessee
# 32  MULTIPOLYGON (((-79.50795 33.02008, -79.50713 ...        South Carolina
# 36  POLYGON ((-75.5591 39.62906, -75.55945 39.6298...            New Jersey
# 42  MULTIPOLYGON (((-89.40565 36.52816, -89.39868 ...              Kentucky
# 35  POLYGON ((-77.11976 38.93434, -77.11253 38.940...  District Of Columbia
# 47  POLYGON ((-94.61783 36.49941, -94.61765 36.499...              Arkansas
# 50  MULTIPOLYGON (((-72.76143 41.24233, -72.75973 ...           Connecticut
#
#       WIND   TOTAL  SOLAR     ALL  percent
# 31   41439   69837    911   70748     58.6
# 13    9376   17436     50   17486     53.6
# 25   27273   58457    210   58667     46.5
# 2    37012   89236    242   89478     41.4
# 12   14914   39269   3314   42583     35.0
# 46   14477   42069      2   42071     34.4
# 10   11845   39446    129   39575     29.9
# 20   16091   57542   5319   62861     25.6
# 49   14398   57277   2417   59694     24.1
# 14  119855  547295  32325  579620     20.7
# 23    8637   43181    202   43383     19.9
# 38    2339   12512   1152   13664     17.1
# 30    4557   26896    316   27212     16.7
# 45    8954   61692   2416   64108     14.0
# 8     2320   17842   1092   18934     12.3
# 28   21808  177738   3447  181185     12.0
# 29     340    2480    430    2910     11.7
# 19    6775   66703    867   67570     10.0
# 48    8844   90047   2203   92250      9.6
# 11    7550  102961    883  103844      7.3
# 6     8292  120657   1566  122223      6.8
# 39     634    9194   2040   11234      5.6
# 15   14019  216629  68978  285607      4.9
# 4     2089   52287     47   52334      4.0
# 24    4800  124040   6205  130245      3.7
# 44    1738   62549   1564   64113      2.7
# 33     411   16825    302   17127      2.4
# 43    2819  133223   1800  135023      2.1
# 21     683   33497   4835   38332      1.8
# 26     111    6718     18    6736      1.6
# 41     169   10431   1027   11458      1.5
# 18    3258  235925   1389  237314      1.4
# 34    1733  111839  12309  124148      1.4
# 37     482   36001   2325   38326      1.3
# 7      182   19696   5724   25420      0.7
# 27     291   42164  11381   53545      0.5
# 1      529  126553  12216  138769      0.4
# 40       4    4772    344    5116      0.1
# 16       0  139435   1223  140658      0.0
# 3       47   91059   6129   97188      0.0
# 0        0   72933    656   73589      0.0
# 5        0   97785    592   98377      0.0
# 9        0  259798  17804  277602      0.0
# 17       0  129222   8069  137291      0.0
# 22      16   77791   1034   78825      0.0
# 32       0  100853   3351  104204      0.0
# 36      18   64229   4710   68939      0.0
# 42       0   63217    286   63503      0.0
# 35       0     172    231     403      0.0
# 47       0   63196   1194   64390      0.0
# 50      10   40666   1659   42325      0.0

# %%
energy_per_state_gdf = energy_per_state_gdf.to_crs(9311)
energy_per_state_gdf.to_file("data/energy.gpkg")
