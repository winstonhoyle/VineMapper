# %%
import requests

# %%
import geopandas as gpd
import pandas as pd

# %% [markdown]
# ## Get State Data

# %%
file_path = "data/cb_2018_us_state_500k/cb_2018_us_state_500k.shp"
states_df = gpd.read_file(file_path)

# %%
states_df = states_df[["STUSPS", "NAME", "geometry"]]

# %% [markdown]
# ## Get COVID Data

# %%
def get_deaths(row: pd.Series):
    state_code = row["STUSPS"]
    url = f"https://jhucoronavirus.azureedge.net/api/v2/regions/us/{state_code.lower()}.json"
    r = requests.get(url)
    if r.status_code == 200:
        return r.json()["deaths"]["all"]
    else:
        print(row["NAME"])

# %%
states_df["deaths"] = states_df.apply(lambda row: get_deaths(row), axis=1)

# %% [markdown]
# ## Get Population Data

# %%
state_populations = pd.read_excel(
    "data/NST-EST2023-POP.xlsx", sheet_name=None, engine="openpyxl"
)

# %%
state_populations_df = state_populations["NST-EST2023-POP"][
    [
        "table with row headers in column A and column headers in rows 3 through 4. (leading dots indicate sub-parts)",
        "Unnamed: 5",
    ]
]
state_populations_df = state_populations_df.rename(
    columns={
        "table with row headers in column A and column headers in rows 3 through 4. (leading dots indicate sub-parts)": "NAME",
        "Unnamed: 5": "POPULATION",
    }
)
state_populations_df["NAME"] = state_populations_df["NAME"].str[1:]

# %% [markdown]
# ## Merge Data

# %%
states_with_population_df = states_df.merge(state_populations_df, on="NAME", how="left")
states_with_population_df = states_with_population_df[
    ["STUSPS", "POPULATION", "geometry", "NAME", "deaths"]
]

# %%
states_with_population_df = states_with_population_df.dropna()

# %%
states_with_population_df["per_1000"] = states_with_population_df["deaths"] / (
    states_with_population_df["POPULATION"] / 1000
)
states_with_population_df["per_10k"] = states_with_population_df["deaths"] / (
    states_with_population_df["POPULATION"] / 10_000
)
states_with_population_df["per_100k"] = states_with_population_df["deaths"] / (
    states_with_population_df["POPULATION"] / 100000
)
states_with_population_df["per_500k"] = states_with_population_df["deaths"] / (
    states_with_population_df["POPULATION"] / 500_000
)
states_with_population_df["per_1m"] = states_with_population_df["deaths"] / (
    states_with_population_df["POPULATION"] / 1_000_000
)
states_with_population_df["per_capita"] = (
    states_with_population_df["POPULATION"] / states_with_population_df["deaths"]
)

# %%
states_with_population_df = states_with_population_df.to_crs(9311)

# %%
states_with_population_df.to_file("data/covid_deaths.gpkg")

# %%
states_with_population_df
# Out:
#    STUSPS  POPULATION                                           geometry  \
# 0      MS   2939690.0  MULTIPOLYGON (((1109997.773 -1565578.875, 1111...
# 1      NC  10835491.0  MULTIPOLYGON (((2154808.027 -692253.992, 21554...
# 2      OK   4053824.0  POLYGON ((-268912.756 -936547.904, -268600.891...
# 3      VA   8715698.0  MULTIPOLYGON (((2098153.247 -490400.387, 20981...
# 4      WV   1770071.0  POLYGON ((1506482.53 -601393.056, 1506489.516 ...
# 5      LA   4573749.0  MULTIPOLYGON (((1079322.442 -1609024.878, 1079...
# 6      MI  10037261.0  MULTIPOLYGON (((1376542.504 -187676.574, 13766...
# 7      MA   7001399.0  MULTIPOLYGON (((2420778.194 34524.899, 2421697...
# 8      ID   1964726.0  POLYGON ((-1357016.205 78008.02, -1356337.908 ...
# 9      FL  22610726.0  MULTIPOLYGON (((1997726.172 -1929592.915, 1997...
# 10     NE   1978379.0  POLYGON ((-339253.738 -417387.502, -339106.319...
# 11     WA   7812880.0  MULTIPOLYGON (((-1634509.823 627551.89, -16343...
# 12     NM   2114371.0  POLYGON ((-862226.867 -1454497.308, -861997.92...
# 13     PR   3205691.0  MULTIPOLYGON (((3661734.646 -2226951.098, 3662...
# 14     SD    919318.0  POLYGON ((-318857.556 7726.411, -318299.501 77...
# 15     TX  30503301.0  MULTIPOLYGON (((514197.103 -1677430.313, 51428...
# 16     CA  38965193.0  MULTIPOLYGON (((-1717282.257 -1090154.595, -17...
# 17     AL   5108468.0  MULTIPOLYGON (((1149246.956 -1527666.558, 1149...
# 18     GA  11029227.0  MULTIPOLYGON (((1774018.899 -1324581.179, 1774...
# 19     PA  12961683.0  POLYGON ((1619177.315 -262060.235, 1618879.478...
# 20     MO   6196156.0  POLYGON ((357039.741 -482422.694, 357435.659 -...
# 21     CO   5877610.0  POLYGON ((-786602.67 -668516.216, -785169.939 ...
# 22     UT   3417734.0  POLYGON ((-1233486.447 -719056.636, -1233235.8...
# 23     TN   7126489.0  POLYGON ((883547.508 -1059435.53, 883522.954 -...
# 24     WY    584057.0  POLYGON ((-865730.986 59352.206, -864993.905 5...
# 25     NY  19571216.0  MULTIPOLYGON (((2282948.092 -21624.723, 228289...
# 26     KS   2940546.0  POLYGON ((-174863.27 -553289.527, -163353.728 ...
# 27     AK    733406.0  MULTIPOLYGON (((-4288407.995 3426181.085, -428...
# 28     NV   3194176.0  POLYGON ((-1704625.157 -434251.605, -1704218.6...
# 29     IL  12549689.0  POLYGON ((720088.004 -498699.252, 720164.325 -...
# 30     VT    647464.0  POLYGON ((2075870.027 238820.542, 2075640.482 ...
# 31     MT   1132812.0  POLYGON ((-1172889.072 508069.731, -1172583.63...
# 32     IA   3207004.0  POLYGON ((274418.778 -245971.628, 274712.711 -...
# 33     SC   5373555.0  MULTIPOLYGON (((1898434.953 -1099843.186, 1898...
# 34     NH   1402054.0  MULTIPOLYGON (((2326343.717 202530.281, 232642...
# 35     AZ   7431344.0  POLYGON ((-1389045.258 -1265605.408, -1388845....
# 36     DC    678972.0  POLYGON ((1950799.304 -402452.215, 1951231.574...
# 39     NJ   9290841.0  POLYGON ((2057761.964 -289308.055, 2057710.645...
# 40     MD   6180253.0  MULTIPOLYGON (((2067172.995 -478871.787, 20670...
# 41     ME   1395722.0  MULTIPOLYGON (((2495259.496 476081.018, 249525...
# 42     HI   1435138.0  MULTIPOLYGON (((-5544643.961 -943550.462, -554...
# 43     DE   1031890.0  MULTIPOLYGON (((2060773.554 -301785.14, 206090...
# 46     RI   1095962.0  MULTIPOLYGON (((2326214.714 41825.849, 2326258...
# 47     KY   4526154.0  MULTIPOLYGON (((946135.474 -881445.948, 946571...
# 48     OH  11785935.0  MULTIPOLYGON (((1422967.707 -227158.235, 14230...
# 49     WI   5910955.0  MULTIPOLYGON (((1013687.487 121601.135, 101375...
# 50     OR   4233358.0  MULTIPOLYGON (((-1781988.816 403834.726, -1781...
# 51     ND    783926.0  POLYGON ((-296121.109 437082.483, -296107.817 ...
# 52     AR   3067732.0  POLYGON ((482029.856 -928936.291, 482046.307 -...
# 53     IN   6862199.0  POLYGON ((1041911.852 -714123.548, 1042168.307...
# 54     MN   5737915.0  MULTIPOLYGON (((772408.659 380232.264, 772444....
# 55     CT   3617176.0  MULTIPOLYGON (((2226858.014 -42564.968, 222677...
#
#                     NAME  deaths  per_1000    per_10k    per_100k  \
# 0            Mississippi   13370  4.548099  45.480986  454.809861
# 1         North Carolina   28432  2.623970  26.239697  262.396969
# 2               Oklahoma   17972  4.433345  44.333449  443.334491
# 3               Virginia   23666  2.715330  27.153304  271.533043
# 4          West Virginia    7960  4.496995  44.969948  449.699475
# 5              Louisiana   18766  4.102980  41.029799  410.297985
# 6               Michigan   42205  4.204832  42.048324  420.483237
# 7          Massachusetts   24333  3.475448  34.754483  347.544826
# 8                  Idaho    5416  2.756618  27.566185  275.661848
# 9                Florida   86850  3.841097  38.410974  384.109736
# 10              Nebraska    4936  2.494972  24.949719  249.497189
# 11            Washington   15683  2.007326  20.073264  200.732636
# 12            New Mexico    9061  4.285435  42.854352  428.543524
# 13           Puerto Rico    5823  1.816457  18.164570  181.645704
# 14          South Dakota    3190  3.469964  34.699636  346.996360
# 15                 Texas   93390  3.061636  30.616359  306.163585
# 16            California  101159  2.596138  25.961375  259.613753
# 17               Alabama   21032  4.117086  41.170856  411.708559
# 18               Georgia   42489  3.852401  38.524005  385.240054
# 19          Pennsylvania   50398  3.888230  38.882296  388.822964
# 20              Missouri   22870  3.690998  36.909981  369.099810
# 21              Colorado   14181  2.412715  24.127154  241.271537
# 22                  Utah    5298  1.550150  15.501499  155.014989
# 23             Tennessee   29263  4.106230  41.062296  410.622959
# 24               Wyoming    2004  3.431172  34.311720  343.117196
# 25              New York   77157  3.942371  39.423713  394.237129
# 26                Kansas   10066  3.423174  34.231738  342.317379
# 27                Alaska    1486  2.026163  20.261629  202.616286
# 28                Nevada   11922  3.732418  37.324180  373.241800
# 29              Illinois   41496  3.306536  33.065361  330.653612
# 30               Vermont     929  1.434829  14.348288  143.482881
# 31               Montana    3652  3.223836  32.238359  322.383591
# 32                  Iowa   10725  3.344243  33.442428  334.424279
# 33        South Carolina   19600  3.647492  36.474922  364.749221
# 34         New Hampshire    3003  2.141858  21.418576  214.185759
# 35               Arizona   33102  4.454376  44.543760  445.437595
# 36  District of Columbia    1432  2.109071  21.090708  210.907077
# 39            New Jersey   36015  3.876398  38.763983  387.639827
# 40              Maryland   16544  2.676913  26.769131  267.691306
# 41                 Maine    2928  2.097839  20.978390  209.783897
# 42                Hawaii    1841  1.282803  12.828035  128.280347
# 43              Delaware    3324  3.221274  32.212736  322.127359
# 46          Rhode Island    3870  3.531144  35.311443  353.114433
# 47              Kentucky   18130  4.005608  40.056083  400.560829
# 48                  Ohio   41796  3.546261  35.462609  354.626086
# 49             Wisconsin   16375  2.770280  27.702799  277.027993
# 50                Oregon    9373  2.214082  22.140816  221.408159
# 51          North Dakota    2470  3.150808  31.508076  315.080760
# 52              Arkansas   13020  4.244178  42.441778  424.417778
# 53               Indiana   26115  3.805631  38.056314  380.563140
# 54             Minnesota   14870  2.591534  25.915337  259.153368
# 55           Connecticut   12220  3.378326  33.783261  337.832608
#
#        per_500k       per_1m  per_capita
# 0   2274.049305  4548.098609  219.872102
# 1   1311.984847  2623.969694  381.101963
# 2   2216.672455  4433.344911  225.563321
# 3   1357.665215  2715.330430  368.279304
# 4   2248.497377  4496.994753  222.370729
# 5   2051.489927  4102.979853  243.725301
# 6   2102.416187  4204.832374  237.821609
# 7   1737.724132  3475.448264  287.732668
# 8   1378.309240  2756.618480  362.763294
# 9   1920.548681  3841.097362  260.342268
# 10  1247.485947  2494.971894  400.806118
# 11  1003.663182  2007.326364  498.175094
# 12  2142.717621  4285.435243  233.348527
# 13   908.228522  1816.457045  550.522239
# 14  1734.981802  3469.963603  288.187461
# 15  1530.817927  3061.635854  326.622775
# 16  1298.068766  2596.137532  385.187606
# 17  2058.542796  4117.085592  242.890262
# 18  1926.200268  3852.400535  259.578409
# 19  1944.114819  3888.229638  257.186456
# 20  1845.499048  3690.998096  270.929427
# 21  1206.357686  2412.715372  414.470771
# 22   775.074947  1550.149895  645.098905
# 23  2053.114795  4106.229589  243.532413
# 24  1715.585979  3431.171958  291.445609
# 25  1971.185643  3942.371286  253.654445
# 26  1711.586896  3423.173792  292.126565
# 27  1013.081431  2026.162862  493.543742
# 28  1866.209000  3732.418001  267.922832
# 29  1653.268061  3306.536122  302.431295
# 30   717.414405  1434.828809  696.947255
# 31  1611.917953  3223.835906  310.189485
# 32  1672.121394  3344.242789  299.021352
# 33  1823.746105  3647.492210  274.160969
# 34  1070.928794  2141.857589  466.884449
# 35  2227.187976  4454.375951  224.498338
# 36  1054.535386  2109.070772  474.142458
# 39  1938.199136  3876.398272  257.971429
# 40  1338.456532  2676.913065  373.564616
# 41  1048.919484  2097.838968  476.681011
# 42   641.401733  1282.803466  779.542640
# 43  1610.636793  3221.273585  310.436221
# 46  1765.572164  3531.144328  283.194315
# 47  2002.804147  4005.608293  249.649972
# 48  1773.130430  3546.260861  281.987152
# 49  1385.139965  2770.279929  360.974351
# 50  1107.040794  2214.081587  451.654540
# 51  1575.403801  3150.807602  317.378947
# 52  2122.088892  4244.177783  235.616897
# 53  1902.815701  3805.631402  262.768486
# 54  1295.766842  2591.533684  385.871890
# 55  1689.163038  3378.326075  296.004583
