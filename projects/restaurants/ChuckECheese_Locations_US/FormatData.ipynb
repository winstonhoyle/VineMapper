# %%
import re
import json
import time

# %%
from bs4 import BeautifulSoup
import geopandas as gpd
import pandas as pd

# %%
from shapely.geometry import Point
from tqdm.notebook import tqdm

# %%
import requests

# %% [markdown]
# ## Get Chuck E Cheese Data

# %%
headers = {
    "User-Agent": "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/50.0.2661.102 Safari/537.36"
}

# %%
url = "https://locations.chuckecheese.com/browse/"

# %%
r = requests.get(url, headers=headers)

# %%
soup = BeautifulSoup(r.text, "html.parser")

# %%
divs = soup.find_all("div", {"class": "map-list-item is-single"})

# %%
def add_locations(locations_list: list, link: str):
    # Get locations
    r = requests.get(link, headers=headers)
    location_soup = BeautifulSoup(r.text, "html.parser")
    map_script = location_soup.find_all("div", {"id": "map-data-wrapper"})[0].find_all(
        "script"
    )[0]
    script_text = map_script.contents[0].string
    coords = script_text.split('"lat"')
    try:
        for coord in coords[1:]:
            lat = float(re.findall("-?\d+\.?\d*", coord.split("lng")[0])[0])
            lng = float(
                re.findall("-?\d+\.?\d*", coord.split("lng")[1].split("title")[0])[0]
            )
            p = Point(lng, lat)
            locations_list.append(p)
    except Exception as e:
        print(e)
        print(coords)

# %%
location_dict = {}
locations = []
for div in tqdm(divs, desc="Parsing Locations"):
    location_split = div.text.strip().split("(")
    location_dict[location_split[0].strip()] = int(location_split[1][:-1])

    try:
        add_locations(locations_list=locations, link=div.find("a").attrs["href"])
    except Exception as e:
        print(e)
        print(location_url)
    time.sleep(1)
# Out:
# Parsing Locations:   0%|          | 0/49 [00:00<?, ?it/s]

# %%
locations_gdf = gpd.GeoDataFrame(geometry=locations, crs=4326)
locations_gdf = locations_gdf.to_crs(9311)
locations_gdf.to_file("data/locations.gpkg")

# %%
cec_df = pd.DataFrame(list(location_dict.items()), columns=["NAME", "stores"])

# %% [markdown]
# ## Get State Data

# %%
file_path = "data/cb_2018_us_state_500k/cb_2018_us_state_500k.shp"
states_df = gpd.read_file(file_path)

# %%
states_df = states_df[["STUSPS", "NAME", "geometry"]]

# %% [markdown]
# ## Get Population Data

# %%
state_populations = pd.read_excel(
    "data/NST-EST2023-POP.xlsx", sheet_name=None, engine="openpyxl"
)

# %%
state_populations_df = state_populations["NST-EST2023-POP"][
    [
        "table with row headers in column A and column headers in rows 3 through 4. (leading dots indicate sub-parts)",
        "Unnamed: 5",
    ]
]
state_populations_df = state_populations_df.rename(
    columns={
        "table with row headers in column A and column headers in rows 3 through 4. (leading dots indicate sub-parts)": "NAME",
        "Unnamed: 5": "POPULATION",
    }
)
state_populations_df["NAME"] = state_populations_df["NAME"].str[1:]

# %%
states_with_population_df = states_df.merge(state_populations_df, on="NAME", how="left")
states_with_population_df = states_with_population_df[
    ["STUSPS", "POPULATION", "geometry", "NAME"]
]

# %%
states_with_population_df = states_with_population_df.dropna()

# %% [markdown]
# ## Merge Data

# %%
cec_with_population_info_gdf = states_with_population_df.merge(
    cec_df, on="NAME", how="left"
)

# %%
cec_with_population_info_gdf
# Out:
#    STUSPS  POPULATION                                           geometry  \
# 0      MS   2939690.0  MULTIPOLYGON (((-88.50297 30.21524, -88.49176 ...
# 1      NC  10835491.0  MULTIPOLYGON (((-75.72681 35.93584, -75.71827 ...
# 2      OK   4053824.0  POLYGON ((-103.00256 36.52659, -103.00219 36.6...
# 3      VA   8715698.0  MULTIPOLYGON (((-75.74241 37.80835, -75.74151 ...
# 4      WV   1770071.0  POLYGON ((-82.6432 38.16909, -82.643 38.16956,...
# 5      LA   4573749.0  MULTIPOLYGON (((-88.8677 29.86155, -88.86566 2...
# 6      MI  10037261.0  MULTIPOLYGON (((-83.19159 42.03537, -83.18993 ...
# 7      MA   7001399.0  MULTIPOLYGON (((-70.23405 41.28565, -70.22361 ...
# 8      ID   1964726.0  POLYGON ((-117.24267 44.39655, -117.23484 44.3...
# 9      FL  22610726.0  MULTIPOLYGON (((-80.17628 25.52505, -80.17395 ...
# 10     NE   1978379.0  POLYGON ((-104.05342 41.17054, -104.05324 41.1...
# 11     WA   7812880.0  MULTIPOLYGON (((-122.57039 48.53785, -122.5686...
# 12     NM   2114371.0  POLYGON ((-109.05017 31.48, -109.04984 31.4995...
# 13     PR   3205691.0  MULTIPOLYGON (((-65.23805 18.32167, -65.23467 ...
# 14     SD    919318.0  POLYGON ((-104.05788 44.9976, -104.05078 44.99...
# 15     TX  30503301.0  MULTIPOLYGON (((-94.7183 29.72886, -94.71721 2...
# 16     CA  38965193.0  MULTIPOLYGON (((-118.60442 33.47855, -118.5987...
# 17     AL   5108468.0  MULTIPOLYGON (((-88.05338 30.50699, -88.05109 ...
# 18     GA  11029227.0  MULTIPOLYGON (((-81.27939 31.30792, -81.27716 ...
# 19     PA  12961683.0  POLYGON ((-80.51989 40.90666, -80.51909 40.921...
# 20     MO   6196156.0  POLYGON ((-95.77355 40.5782, -95.76853 40.5833...
# 21     CO   5877610.0  POLYGON ((-109.06025 38.59933, -109.05954 38.7...
# 22     UT   3417734.0  POLYGON ((-114.05296 37.59278, -114.05247 37.6...
# 23     TN   7126489.0  POLYGON ((-90.3103 35.0043, -90.30988 35.00975...
# 24     WY    584057.0  POLYGON ((-111.05456 45.00096, -111.04507 45.0...
# 25     NY  19571216.0  MULTIPOLYGON (((-72.03683 41.24984, -72.03496 ...
# 26     KS   2940546.0  POLYGON ((-102.05174 40.00308, -101.9167 40.00...
# 27     AK    733406.0  MULTIPOLYGON (((179.48246 51.98283, 179.48656 ...
# 28     NV   3194176.0  POLYGON ((-120.00574 39.22866, -120.00559 39.2...
# 29     IL  12549689.0  POLYGON ((-91.51297 40.18106, -91.51107 40.188...
# 30     VT    647464.0  POLYGON ((-73.43774 44.04501, -73.43199 44.063...
# 31     MT   1132812.0  POLYGON ((-116.04914 48.50205, -116.04913 48.5...
# 32     IA   3207004.0  POLYGON ((-96.6397 42.73707, -96.63589 42.741,...
# 33     SC   5373555.0  MULTIPOLYGON (((-79.50795 33.02008, -79.50713 ...
# 34     NH   1402054.0  MULTIPOLYGON (((-70.61702 42.97718, -70.61529 ...
# 35     AZ   7431344.0  POLYGON ((-114.81629 32.50804, -114.81432 32.5...
# 36     DC    678972.0  POLYGON ((-77.11976 38.93434, -77.11253 38.940...
# 37     NJ   9290841.0  POLYGON ((-75.5591 39.62906, -75.55945 39.6298...
# 38     MD   6180253.0  MULTIPOLYGON (((-76.05015 37.9869, -76.04998 3...
# 39     ME   1395722.0  MULTIPOLYGON (((-67.3558 44.64226, -67.35437 4...
# 40     HI   1435138.0  MULTIPOLYGON (((-156.06076 19.73055, -156.0566...
# 41     DE   1031890.0  MULTIPOLYGON (((-75.56555 39.51485, -75.56174 ...
# 42     RI   1095962.0  MULTIPOLYGON (((-71.28802 41.64558, -71.28647 ...
# 43     KY   4526154.0  MULTIPOLYGON (((-89.40565 36.52816, -89.39868 ...
# 44     OH  11785935.0  MULTIPOLYGON (((-82.73571 41.60336, -82.73392 ...
# 45     WI   5910955.0  MULTIPOLYGON (((-86.95617 45.35549, -86.95463 ...
# 46     OR   4233358.0  MULTIPOLYGON (((-123.59892 46.25145, -123.5984...
# 47     ND    783926.0  POLYGON ((-104.04868 48.86378, -104.04865 48.8...
# 48     AR   3067732.0  POLYGON ((-94.61783 36.49941, -94.61765 36.499...
# 49     IN   6862199.0  POLYGON ((-88.09776 37.90403, -88.09448 37.905...
# 50     MN   5737915.0  MULTIPOLYGON (((-89.59206 47.96668, -89.59147 ...
# 51     CT   3617176.0  MULTIPOLYGON (((-72.76143 41.24233, -72.75973 ...
#
#                     NAME  stores
# 0            Mississippi     5.0
# 1         North Carolina    13.0
# 2               Oklahoma     6.0
# 3               Virginia    15.0
# 4          West Virginia     1.0
# 5              Louisiana     9.0
# 6               Michigan    12.0
# 7          Massachusetts     6.0
# 8                  Idaho     1.0
# 9                Florida    31.0
# 10              Nebraska     1.0
# 11            Washington    10.0
# 12            New Mexico     3.0
# 13           Puerto Rico     NaN
# 14          South Dakota     NaN
# 15                 Texas    62.0
# 16            California    76.0
# 17               Alabama     9.0
# 18               Georgia    13.0
# 19          Pennsylvania    14.0
# 20              Missouri     7.0
# 21              Colorado     7.0
# 22                  Utah     2.0
# 23             Tennessee    11.0
# 24               Wyoming     NaN
# 25              New York    21.0
# 26                Kansas     4.0
# 27                Alaska     1.0
# 28                Nevada     7.0
# 29              Illinois    19.0
# 30               Vermont     NaN
# 31               Montana     1.0
# 32                  Iowa     2.0
# 33        South Carolina     6.0
# 34         New Hampshire     1.0
# 35               Arizona     5.0
# 36  District of Columbia     NaN
# 37            New Jersey    13.0
# 38              Maryland    12.0
# 39                 Maine     NaN
# 40                Hawaii     3.0
# 41              Delaware     2.0
# 42          Rhode Island     1.0
# 43              Kentucky     5.0
# 44                  Ohio    16.0
# 45             Wisconsin     8.0
# 46                Oregon     3.0
# 47          North Dakota     NaN
# 48              Arkansas     6.0
# 49               Indiana    11.0
# 50             Minnesota     5.0
# 51           Connecticut     3.0

# %%
cec_with_population_info_gdf["per_1000"] = cec_with_population_info_gdf["stores"] / (
    cec_with_population_info_gdf["POPULATION"] / 1000
)
cec_with_population_info_gdf["per_10k"] = cec_with_population_info_gdf["stores"] / (
    cec_with_population_info_gdf["POPULATION"] / 10_000
)
cec_with_population_info_gdf["per_100k"] = cec_with_population_info_gdf["stores"] / (
    cec_with_population_info_gdf["POPULATION"] / 100000
)
cec_with_population_info_gdf["per_500k"] = cec_with_population_info_gdf["stores"] / (
    cec_with_population_info_gdf["POPULATION"] / 500_000
)
cec_with_population_info_gdf["per_1m"] = cec_with_population_info_gdf["stores"] / (
    cec_with_population_info_gdf["POPULATION"] / 1_000_000
)
cec_with_population_info_gdf["per_capita"] = (
    cec_with_population_info_gdf["POPULATION"] / cec_with_population_info_gdf["stores"]
)

# %%
cec_with_population_info_gdf = cec_with_population_info_gdf.to_crs(9311)

# %%
cec_with_population_info_gdf.to_file("data/cec.gpkg")

# %%
3 / (3206000 / 1_000_000)
# Out:
# 0.9357454772301934
