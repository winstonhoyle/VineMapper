# %%
import geopandas as gpd
import pandas as pd

# %% [markdown]
# ## Open State data

# %%
file_path = "data/cb_2024_us_county_500k/cb_2024_us_county_500k.shp"
counties_gdf = gpd.read_file(file_path)
counties_gdf = counties_gdf.to_crs(4326)

# %% [markdown]
# ## Get Language

# %%
language_df = pd.read_csv(
    "data/ACSST5Y2023.S1603_2025-06-16T011229/ACSST5Y2023.S1603-Data.csv",
    low_memory=False,
)

# %% [markdown]
# #### Get Column names

# %%
acs_column_names = pd.read_csv(
    "data/ACSST5Y2023.S1603_2025-06-16T011229/ACSST5Y2023.S1603-Column-Metadata.csv"
)

# %%
col_renames = {
    "Estimate!!Total!!Total population 5 years and over": "POPULATION",
    "Estimate!!Total!!Speak a language other than English at home!!Total population 5 years and over": "POPULATION_NOT_ENGLISH_AT_HOME",
    "Estimate!!Speak Spanish at home!!Speak a language other than English at home!!Total population 5 years and over": "POPULATION_SPANISH_AT_HOME",
    "Geography": "GEOIDFQ",
}

# %%
language_cols = list(
    acs_column_names[
        (acs_column_names["Column Name"] == "S1603_C01_001E")
        | (acs_column_names["Column Name"] == "S1603_C04_001E")
        | (acs_column_names["Column Name"] == "S1603_C06_001E")
    ]["Column Name"]
)

# %% [markdown]
# #### Back to Data

# %%
language_df = language_df[["GEO_ID", *language_cols]]
language_df.columns = language_df.iloc[0]
language_df = language_df[1:]
language_df = language_df.rename(columns=col_renames)

# %%
language_df["POPULATION"] = language_df["POPULATION"].astype(int)
language_df["POPULATION_NOT_ENGLISH_AT_HOME"] = language_df[
    "POPULATION_NOT_ENGLISH_AT_HOME"
].astype(int)
language_df["POPULATION_SPANISH_AT_HOME"] = language_df[
    "POPULATION_SPANISH_AT_HOME"
].astype(int)

# %% [markdown]
# ## Merge Data

# %%
language_gdf = counties_gdf.merge(language_df, on="GEOIDFQ", how="left")

# %%
language_gdf["POPULATION_LANGUAGE_NOT_ENGLISH_NOT_SPANISH"] = (
    language_gdf["POPULATION_NOT_ENGLISH_AT_HOME"]
    - language_gdf["POPULATION_SPANISH_AT_HOME"]
)
language_gdf["PERCENT_POPULATION_LANGUAGE_NOT_ENGLISH_NOT_SPANISH"] = (
    (
        language_gdf["POPULATION_LANGUAGE_NOT_ENGLISH_NOT_SPANISH"]
        / language_gdf["POPULATION"]
    )
    * 100
).round(decimals=2)
language_gdf["PERCENT_POPULATION_LANGUAGE_SPANISH_AT_HOME"] = (
    (language_gdf["POPULATION_SPANISH_AT_HOME"] / language_gdf["POPULATION"]) * 100
).round(decimals=2)

# %%
language_gdf = language_gdf.dropna()

# %%
language_gdf = language_gdf.to_crs(9311)
language_gdf[language_gdf["STUSPS"] != "PR"].to_file("data/language.gpkg")

# %%
language_gdf[language_gdf["STUSPS"] != "PR"].sort_values(
    "PERCENT_POPULATION_LANGUAGE_SPANISH_AT_HOME", ascending=False
)
# Out:
#      STATEFP COUNTYFP  COUNTYNS         GEOIDFQ  GEOID      NAME  \
# 497       48      427  01383999  0500000US48427  48427     Starr
# 264       48      261  01383916  0500000US48261  48261    Kenedy
# 1331      48      323  01383944  0500000US48323  48323  Maverick
# 2004      48      479  01384025  0500000US48479  48479      Webb
# 3072      48      505  01384038  0500000US48505  48505    Zapata
# ...      ...      ...       ...             ...    ...       ...
# 1099      46      069  01266984  0500000US46069  46069      Hyde
# 1587      39      163  01074093  0500000US39163  39163    Vinton
# 2259      46      017  01265767  0500000US46017  46017   Buffalo
# 1958      38      091  01034220  0500000US38091  38091    Steele
# 1959      38      083  01034203  0500000US38083  38083  Sheridan
#
#              NAMELSAD STUSPS    STATE_NAME LSAD       ALAND      AWATER  \
# 497      Starr County     TX         Texas   06  3168019235    15386849
# 264     Kenedy County     TX         Texas   06  3777657843  1261927310
# 1331  Maverick County     TX         Texas   06  3313828190    31862966
# 2004      Webb County     TX         Texas   06  8706239656    36502178
# 3072    Zapata County     TX         Texas   06  2585876042   154371160
# ...               ...    ...           ...  ...         ...         ...
# 1099      Hyde County     SD  South Dakota   06  2229019409    14541548
# 1587    Vinton County     OH          Ohio   06  1068008170     6781751
# 2259   Buffalo County     SD  South Dakota   06  1220933806    42362357
# 1958    Steele County     ND  North Dakota   06  1844441513     8435674
# 1959  Sheridan County     ND  North Dakota   06  2518053313    86198847
#
#                                                geometry  POPULATION  \
# 497   POLYGON ((83531.908 -2042353.274, 83703.676 -2...     59754.0
# 264   MULTIPOLYGON (((261305.708 -2003968.269, 26196...        52.0
# 1331  POLYGON ((-65458.283 -1763836.238, -61370.81 -...     52728.0
# 2004  POLYGON ((-20981.285 -1861741.168, -11229.076 ...    245610.0
# 3072  POLYGON ((54674.439 -1964034.942, 57501.664 -1...     12761.0
# ...                                                 ...         ...
# 1099  POLYGON ((25701.394 -40545.573, 25697.542 -365...      1210.0
# 1587  POLYGON ((1473414.27 -486529.21, 1473214.302 -...     11978.0
# 2259  POLYGON ((33803.985 -89691.581, 36614.63 -8962...      1544.0
# 1958  POLYGON ((151782.787 262166.366, 151757.595 26...      1626.0
# 1959  POLYGON ((-50529.821 280853.787, -50512.364 28...      1267.0
#
#       POPULATION_NOT_ENGLISH_AT_HOME  POPULATION_SPANISH_AT_HOME  \
# 497                          55260.0                     55241.0
# 264                             47.0                        46.0
# 1331                         46911.0                     46271.0
# 2004                        216461.0                    214430.0
# 3072                         10839.0                     10758.0
# ...                              ...                         ...
# 1099                            12.0                         0.0
# 1587                           179.0                         0.0
# 2259                            25.0                         0.0
# 1958                            23.0                         0.0
# 1959                            29.0                         0.0
#
#       POPULATION_LANGUAGE_NOT_ENGLISH_NOT_SPANISH  \
# 497                                          19.0
# 264                                           1.0
# 1331                                        640.0
# 2004                                       2031.0
# 3072                                         81.0
# ...                                           ...
# 1099                                         12.0
# 1587                                        179.0
# 2259                                         25.0
# 1958                                         23.0
# 1959                                         29.0
#
#       PERCENT_POPULATION_LANGUAGE_NOT_ENGLISH_NOT_SPANISH  \
# 497                                                0.03
# 264                                                1.92
# 1331                                               1.21
# 2004                                               0.83
# 3072                                               0.63
# ...                                                 ...
# 1099                                               0.99
# 1587                                               1.49
# 2259                                               1.62
# 1958                                               1.41
# 1959                                               2.29
#
#       PERCENT_POPULATION_LANGUAGE_SPANISH_AT_HOME
# 497                                         92.45
# 264                                         88.46
# 1331                                        87.75
# 2004                                        87.31
# 3072                                        84.30
# ...                                           ...
# 1099                                         0.00
# 1587                                         0.00
# 2259                                         0.00
# 1958                                         0.00
# 1959                                         0.00
#
# [3144 rows x 19 columns]
