# %%
import geopandas as gpd
import pandas as pd

# %% [markdown]
# ## Open State data

# %%
file_path = "data/cb_2024_us_county_500k/cb_2024_us_county_500k.shp"
counties_gdf = gpd.read_file(file_path)
counties_gdf = counties_gdf.to_crs(4326)

# %% [markdown]
# ## Get Language

# %%
language_df = pd.read_csv(
    "data/ACSST5Y2023.S1603_2025-06-16T011229/ACSST5Y2023.S1603-Data.csv",
    low_memory=False,
)

# %% [markdown]
# #### Get Column names

# %%
acs_column_names = pd.read_csv(
    "data/ACSST5Y2023.S1603_2025-06-16T011229/ACSST5Y2023.S1603-Column-Metadata.csv"
)

# %%
col_renames = {
    "Estimate!!Total!!Total population 5 years and over": "POPULATION",
    "Estimate!!Total!!Speak a language other than English at home!!Total population 5 years and over": "POPULATION_NOT_ENGLISH_AT_HOME",
    "Estimate!!Speak Spanish at home!!Speak a language other than English at home!!Total population 5 years and over": "POPULATION_SPANISH_AT_HOME",
    "Geography": "GEOIDFQ",
}

# %%
language_cols = list(
    acs_column_names[
        (acs_column_names["Column Name"] == "S1603_C01_001E")
        | (acs_column_names["Column Name"] == "S1603_C04_001E")
        | (acs_column_names["Column Name"] == "S1603_C06_001E")
    ]["Column Name"]
)

# %% [markdown]
# #### Back to Data

# %%
language_df = language_df[["GEO_ID", *language_cols]]
language_df.columns = language_df.iloc[0]
language_df = language_df[1:]
language_df = language_df.rename(columns=col_renames)

# %%
language_df["POPULATION"] = language_df["POPULATION"].astype(int)
language_df["POPULATION_NOT_ENGLISH_AT_HOME"] = language_df[
    "POPULATION_NOT_ENGLISH_AT_HOME"
].astype(int)
language_df["POPULATION_SPANISH_AT_HOME"] = language_df[
    "POPULATION_SPANISH_AT_HOME"
].astype(int)

# %% [markdown]
# ## Merge Data

# %%
language_gdf = counties_gdf.merge(language_df, on="GEOIDFQ", how="left")

# %%
language_gdf["POPULATION_LANGUAGE_NOT_ENGLISH_NOT_SPANISH"] = (
    language_gdf["POPULATION_NOT_ENGLISH_AT_HOME"]
    - language_gdf["POPULATION_SPANISH_AT_HOME"]
)
language_gdf["PERCENT_POPULATION_LANGUAGE_NOT_ENGLISH_NOT_SPANISH"] = (
    (
        language_gdf["POPULATION_LANGUAGE_NOT_ENGLISH_NOT_SPANISH"]
        / language_gdf["POPULATION"]
    )
    * 100
).round(decimals=2)

# %%
language_gdf = language_gdf.dropna()

# %%
language_gdf = language_gdf.to_crs(9311)
language_gdf.to_file("data/language.gpkg")

# %%
language_gdf.sort_values(
    "PERCENT_POPULATION_LANGUAGE_NOT_ENGLISH_NOT_SPANISH", ascending=False
)
# Out:
#      STATEFP COUNTYFP  COUNTYNS         GEOIDFQ  GEOID            NAME  \
# 886       02      050  01419966  0500000US02050  02050          Bethel
# 319       04      001  00025441  0500000US04001  04001          Apache
# 2350      39      075  01074050  0500000US39075  39075          Holmes
# 2387      02      016  01419965  0500000US02016  02016  Aleutians West
# 2999      35      031  00929107  0500000US35031  35031        McKinley
# ...      ...      ...       ...             ...    ...             ...
# 3050      72      149  01804555  0500000US72149  72149        Villalba
# 3061      72      027  01804493  0500000US72027  72027           Camuy
# 3208      49      031  01448029  0500000US49031  49031           Piute
# 3198      72      085  01804523  0500000US72085  72085     Las Piedras
# 3197      48      047  01383809  0500000US48047  48047          Brooks
#
#                         NAMELSAD STUSPS   STATE_NAME LSAD         ALAND  \
# 886           Bethel Census Area     AK       Alaska   05  105310429084
# 319                Apache County     AZ      Arizona   06   29003487955
# 2350               Holmes County     OH         Ohio   06    1094566305
# 2387  Aleutians West Census Area     AK       Alaska   05   11377949308
# 2999             McKinley County     NM   New Mexico   06   14118189295
# ...                          ...    ...          ...  ...           ...
# 3050          Villalba Municipio     PR  Puerto Rico   13      92200653
# 3061             Camuy Municipio     PR  Puerto Rico   13     120259577
# 3208                Piute County     UT         Utah   06    1963753824
# 3198       Las Piedras Municipio     PR  Puerto Rico   13      87748419
# 3197               Brooks County     TX        Texas   06    2443277014
#
#            AWATER                                           geometry  \
# 886   12678050559  MULTIPOLYGON (((-3101902.04 2893602.272, -3101...
# 319      54140333  POLYGON ((-887636.263 -836070.038, -887635.984...
# 2350      3694365  POLYGON ((1486161.522 -320411.558, 1486197.987...
# 2387  25183571468  MULTIPOLYGON (((-4288407.995 3426181.085, -428...
# 2999     12689169  POLYGON ((-821272.444 -1026257.454, -821097.93...
# ...           ...                                                ...
# 3050      3595301  POLYGON ((3539506.685 -2301734.089, 3539531.75...
# 3061     40304880  POLYGON ((3491696.17 -2276406.736, 3492711.031...
# 3208     20286511  POLYGON ((-1086336.197 -642608.539, -1086014.3...
# 3198        32509  POLYGON ((3598485.329 -2274064.031, 3598671.26...
# 3197       741627  POLYGON ((146412.592 -1962970.487, 147749.087 ...
#
#       POPULATION  POPULATION_NOT_ENGLISH_AT_HOME  POPULATION_SPANISH_AT_HOME  \
# 886      16530.0                          9875.0                        66.0
# 319      61741.0                         32320.0                      1420.0
# 2350     40624.0                         20371.0                       149.0
# 2387      5059.0                          2839.0                       478.0
# 2999     66961.0                         34007.0                      3640.0
# ...          ...                             ...                         ...
# 3050     20893.0                         20090.0                     20090.0
# 3061     31672.0                         30496.0                     30496.0
# 3208      1649.0                            83.0                        83.0
# 3198     33897.0                         33078.0                     33078.0
# 3197      6770.0                          4685.0                      4685.0
#
#       POPULATION_LANGUAGE_NOT_ENGLISH_NOT_SPANISH  \
# 886                                        9809.0
# 319                                       30900.0
# 2350                                      20222.0
# 2387                                       2361.0
# 2999                                      30367.0
# ...                                           ...
# 3050                                          0.0
# 3061                                          0.0
# 3208                                          0.0
# 3198                                          0.0
# 3197                                          0.0
#
#       PERCENT_POPULATION_LANGUAGE_NOT_ENGLISH_NOT_SPANISH
# 886                                               59.34
# 319                                               50.05
# 2350                                              49.78
# 2387                                              46.67
# 2999                                              45.35
# ...                                                 ...
# 3050                                               0.00
# 3061                                               0.00
# 3208                                               0.00
# 3198                                               0.00
# 3197                                               0.00
#
# [3222 rows x 18 columns]
