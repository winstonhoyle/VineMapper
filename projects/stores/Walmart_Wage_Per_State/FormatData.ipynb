# %%
import httpx
import json
import os
import re

# %%
import demjson3
import geopandas as gpd
import pandas as pd

# %% [markdown]
# ## Get State Data

# %%
file_path = "data/cb_2018_us_state_500k/cb_2018_us_state_500k.shp"
states_df = gpd.read_file(file_path)

# %%
states_df = states_df[["STUSPS", "NAME", "geometry"]]

# %% [markdown]
# ## Get Population data

# %%
state_populations = pd.read_excel(
    "data/NST-EST2024-POP.xlsx", sheet_name=None, engine="openpyxl"
)

# %%
state_populations_df = state_populations["NST-EST2024-POP"][
    [
        "table with row headers in column A and column headers in rows 3 through 4. (leading dots indicate sub-parts)",
        "Unnamed: 5",
    ]
]
state_populations_df = state_populations_df.rename(
    columns={
        "table with row headers in column A and column headers in rows 3 through 4. (leading dots indicate sub-parts)": "NAME",
        "Unnamed: 5": "POPULATION",
    }
)
state_populations_df["NAME"] = state_populations_df["NAME"].str[1:]

# %%
states_with_population_df = states_df.merge(state_populations_df, on="NAME", how="left")
states_with_population_df = states_with_population_df[
    ["STUSPS", "NAME", "POPULATION", "geometry"]
]

# %% [markdown]
# ## Get Walmart Data

# %%
url = "https://corporate.walmart.com/content/dam/corporate/documents/about/location-facts/locations.js"
r = httpx.get(url)
js_text = r.text

# %%
match = re.search(r"var\s+locationFacts\s*=\s*(\{.*\});?", js_text, re.DOTALL)

# %%
js_object_text = match.group(1)
js_object_text = re.sub(
    r"`([\s\S]*?)`",  # Match multiline content inside backticks
    lambda m: '"' + m.group(1).replace('"', '\\"').replace("\n", "\\n") + '"',
    js_object_text,
)
location_facts = demjson3.decode(js_object_text)

# %%
for state, state_data in location_facts.items():
    stats = state_data.pop("stats", None)
    if stats:
        state_data.update(stats)

# %%
for state, state_data in location_facts.items():
    for section in ["footprintTable", "footprintGrid"]:
        section_data = state_data.pop(section, None)
        if section_data:
            # Prefix keys if needed to avoid overwriting
            prefixed = {f"{section}_{k}": v for k, v in section_data.items()}
            state_data.update(prefixed)

# %%
walmart_df = pd.DataFrame(location_facts.values())
walmart_df = walmart_df[
    [
        "state",
        "footprintTable_totalRetailUnits",
        "footprintTable_samsClub",
        "footprintGrid_numberOfAssociates",
        "footprintGrid_averageWage",
    ]
]
walmart_df = walmart_df.replace(to_replace={"N/A": "0", ",": "", r"\$": ""}, regex=True)

# %%
walmart_df = walmart_df.rename(
    columns={
        "state": "NAME",
        "footprintTable_totalRetailUnits": "UNITS",
        "footprintTable_samsClub": "SAMS_CLUBS",
        "footprintGrid_numberOfAssociates": "WORKERS",
        "footprintGrid_averageWage": "AVG_WAGE",
    }
)

# %%
walmart_df[["UNITS", "SAMS_CLUBS", "WORKERS"]] = walmart_df[
    ["UNITS", "SAMS_CLUBS", "WORKERS"]
].astype(int)
walmart_df["AVG_WAGE"] = walmart_df["AVG_WAGE"].astype(float)
walmart_df["WALMARTS"] = walmart_df["UNITS"] - walmart_df["SAMS_CLUBS"]

# %% [markdown]
# ## Combine With States

# %%
walmart_gdf = states_with_population_df.merge(walmart_df, on="NAME", how="left")

# %%
walmart_gdf = walmart_gdf.fillna(0)

# %%
walmart_gdf["per_100k"] = (
    walmart_gdf["WALMARTS"] / (walmart_gdf["POPULATION"] / 100_000)
).round(decimals=1)
walmart_gdf["per_1m"] = (
    walmart_gdf["WALMARTS"] / (walmart_gdf["POPULATION"] / 1_000_000)
).round(decimals=1)
walmart_gdf["workers_per_unit"] = (walmart_gdf["WORKERS"] / walmart_gdf["UNITS"]).round(
    decimals=1
)

# %%
walmart_gdf = walmart_gdf.fillna(0)

# %%
walmart_gdf = walmart_gdf.to_crs(9311)
walmart_gdf.to_file(f"data/walmarts_per_state.gpkg")

# %%
walmart_gdf
# Out:
#    STUSPS                                          NAME  POPULATION  \
# 0      MS                                   Mississippi   2943172.0
# 1      NC                                North Carolina  10881189.0
# 2      OK                                      Oklahoma   4063882.0
# 3      VA                                      Virginia   8734685.0
# 4      WV                                 West Virginia   1770495.0
# 5      LA                                     Louisiana   4588071.0
# 6      MI                                      Michigan  10083356.0
# 7      MA                                 Massachusetts   7066568.0
# 8      ID                                         Idaho   1971122.0
# 9      FL                                       Florida  22904868.0
# 10     NE                                      Nebraska   1987864.0
# 11     WA                                    Washington   7857320.0
# 12     NM                                    New Mexico   2121164.0
# 13     PR                                   Puerto Rico   3203792.0
# 14     SD                                  South Dakota    918305.0
# 15     TX                                         Texas  30727890.0
# 16     CA                                    California  39198693.0
# 17     AL                                       Alabama   5117673.0
# 18     GA                                       Georgia  11064432.0
# 19     PA                                  Pennsylvania  13017721.0
# 20     MO                                      Missouri   6208038.0
# 21     CO                                      Colorado   5901339.0
# 22     UT                                          Utah   3443222.0
# 23     TN                                     Tennessee   7148304.0
# 24     WY                                       Wyoming    585067.0
# 25     NY                                      New York  19737367.0
# 26     KS                                        Kansas   2951500.0
# 27     AK                                        Alaska    736510.0
# 28     NV                                        Nevada   3214363.0
# 29     IL                                      Illinois  12642259.0
# 30     VT                                       Vermont    648708.0
# 31     MT                                       Montana   1131302.0
# 32     IA                                          Iowa   3218414.0
# 33     SC                                South Carolina   5387830.0
# 34     NH                                 New Hampshire   1402199.0
# 35     AZ                                       Arizona   7473027.0
# 36     DC                          District of Columbia    687324.0
# 37     AS                                American Samoa         0.0
# 38     VI                  United States Virgin Islands         0.0
# 39     NJ                                    New Jersey   9379642.0
# 40     MD                                      Maryland   6217062.0
# 41     ME                                         Maine   1399646.0
# 42     HI                                        Hawaii   1441387.0
# 43     DE                                      Delaware   1036423.0
# 44     GU                                          Guam         0.0
# 45     MP  Commonwealth of the Northern Mariana Islands         0.0
# 46     RI                                  Rhode Island   1103429.0
# 47     KY                                      Kentucky   4550595.0
# 48     OH                                          Ohio  11824034.0
# 49     WI                                     Wisconsin   5930405.0
# 50     OR                                        Oregon   4253653.0
# 51     ND                                  North Dakota    789047.0
# 52     AR                                      Arkansas   3069463.0
# 53     IN                                       Indiana   6880131.0
# 54     MN                                     Minnesota   5753048.0
# 55     CT                                   Connecticut   3643023.0
#
#                                              geometry  UNITS  SAMS_CLUBS  \
# 0   MULTIPOLYGON (((1109997.773 -1565578.875, 1111...   86.0         7.0
# 1   MULTIPOLYGON (((2154808.027 -692253.992, 21554...  214.0        22.0
# 2   POLYGON ((-268912.756 -936547.904, -268600.891...  134.0        13.0
# 3   MULTIPOLYGON (((2098153.247 -490400.387, 20981...  148.0        15.0
# 4   POLYGON ((1506482.53 -601393.056, 1506489.516 ...   44.0         5.0
# 5   MULTIPOLYGON (((1079322.442 -1609024.878, 1079...  137.0        14.0
# 6   MULTIPOLYGON (((1376542.504 -187676.574, 13766...  117.0        23.0
# 7   MULTIPOLYGON (((2420778.194 34524.899, 2421697...   48.0         0.0
# 8   POLYGON ((-1357016.205 78008.02, -1356337.908 ...   27.0         1.0
# 9   MULTIPOLYGON (((1997726.172 -1929592.915, 1997...  387.0        46.0
# 10  POLYGON ((-339253.738 -417387.502, -339106.319...   47.0         5.0
# 11  MULTIPOLYGON (((-1634509.823 627551.89, -16343...   64.0         0.0
# 12  POLYGON ((-862226.867 -1454497.308, -861997.92...   52.0         7.0
# 13  MULTIPOLYGON (((3661734.646 -2226951.098, 3662...   25.0         7.0
# 14  POLYGON ((-318857.556 7726.411, -318299.501 77...   17.0         2.0
# 15  MULTIPOLYGON (((514197.103 -1677430.313, 51428...  592.0        82.0
# 16  MULTIPOLYGON (((-1717282.257 -1090154.595, -17...  303.0        30.0
# 17  MULTIPOLYGON (((1149246.956 -1527666.558, 1149...  143.0        13.0
# 18  MULTIPOLYGON (((1774018.899 -1324581.179, 1774...  209.0        24.0
# 19  POLYGON ((1619177.315 -262060.235, 1618879.478...  159.0        24.0
# 20  POLYGON ((357039.741 -482422.694, 357435.659 -...  156.0        19.0
# 21  POLYGON ((-786602.67 -668516.216, -785169.939 ...  104.0        17.0
# 22  POLYGON ((-1233486.447 -719056.636, -1233235.8...   59.0         8.0
# 23  POLYGON ((883547.508 -1059435.53, 883522.954 -...  150.0        14.0
# 24  POLYGON ((-865730.986 59352.206, -864993.905 5...   14.0         2.0
# 25  MULTIPOLYGON (((2282948.092 -21624.723, 228289...  111.0        12.0
# 26  POLYGON ((-174863.27 -553289.527, -163353.728 ...   82.0         9.0
# 27  MULTIPOLYGON (((-4288407.995 3426181.085, -428...    9.0         0.0
# 28  POLYGON ((-1704625.157 -434251.605, -1704218.6...   50.0         7.0
# 29  POLYGON ((720088.004 -498699.252, 720164.325 -...  177.0        25.0
# 30  POLYGON ((2075870.027 238820.542, 2075640.482 ...    6.0         0.0
# 31  POLYGON ((-1172889.072 508069.731, -1172583.63...   16.0         2.0
# 32  POLYGON ((274418.778 -245971.628, 274712.711 -...   69.0         9.0
# 33  MULTIPOLYGON (((1898434.953 -1099843.186, 1898...  122.0        13.0
# 34  MULTIPOLYGON (((2326343.717 202530.281, 232642...   28.0         2.0
# 35  POLYGON ((-1389045.258 -1265605.408, -1388845....  124.0        12.0
# 36  POLYGON ((1950799.304 -402452.215, 1951231.574...    2.0         0.0
# 37  MULTIPOLYGON (((-7799029.401 -3753736.013, -77...    0.0         0.0
# 38  MULTIPOLYGON (((3738151.501 -2258200.246, 3738...    0.0         0.0
# 39  POLYGON ((2057761.964 -289308.055, 2057710.645...   70.0         8.0
# 40  MULTIPOLYGON (((2067172.995 -478871.787, 20670...   58.0        11.0
# 41  MULTIPOLYGON (((2495259.496 476081.018, 249525...   25.0         3.0
# 42  MULTIPOLYGON (((-5544643.961 -943550.462, -554...   11.0         2.0
# 43  MULTIPOLYGON (((2060773.554 -301785.14, 206090...   10.0         1.0
# 44  MULTIPOLYGON (((-8511256.588 4418401.614, -851...    0.0         0.0
# 45  MULTIPOLYGON (((-8256087.661 4425498.185, -825...    0.0         0.0
# 46  MULTIPOLYGON (((2326214.714 41825.849, 2326258...    9.0         0.0
# 47  MULTIPOLYGON (((946135.474 -881445.948, 946571...  101.0         9.0
# 48  MULTIPOLYGON (((1422967.707 -227158.235, 14230...  169.0        27.0
# 49  MULTIPOLYGON (((1013687.487 121601.135, 101375...   97.0        10.0
# 50  MULTIPOLYGON (((-1781988.816 403834.726, -1781...   43.0         0.0
# 51  POLYGON ((-296121.109 437082.483, -296107.817 ...   17.0         3.0
# 52  POLYGON ((482029.856 -928936.291, 482046.307 -...  127.0        10.0
# 53  POLYGON ((1041911.852 -714123.548, 1042168.307...  126.0        13.0
