# %%
import json
import requests

# %%
import geopandas as gpd
import pandas as pd

# %%
from bs4 import BeautifulSoup
from shapely.geometry import Point
from tqdm.notebook import tqdm

# %% [markdown]
# ## Get State Data

# %%
file_path = "data/cb_2018_us_state_500k/cb_2018_us_state_500k.shp"
states_df = gpd.read_file(file_path)

# %%
states_df = states_df[["STUSPS", "NAME", "geometry"]]

# %% [markdown]
# ## Get Population data

# %%
state_populations = pd.read_excel(
    "data/NST-EST2024-POP.xlsx", sheet_name=None, engine="openpyxl"
)

# %%
state_populations_df = state_populations["NST-EST2024-POP"][
    [
        "table with row headers in column A and column headers in rows 3 through 4. (leading dots indicate sub-parts)",
        "Unnamed: 5",
    ]
]
state_populations_df = state_populations_df.rename(
    columns={
        "table with row headers in column A and column headers in rows 3 through 4. (leading dots indicate sub-parts)": "NAME",
        "Unnamed: 5": "POPULATION",
    }
)
state_populations_df["NAME"] = state_populations_df["NAME"].str[1:]

# %%
states_with_population_df = states_df.merge(state_populations_df, on="NAME", how="left")
states_with_population_df = states_with_population_df[
    ["STUSPS", "NAME", "POPULATION", "geometry"]
]

# %% [markdown]
# ## Get Store Data

# %%
url = "https://maps.spirithalloween.com/api/getAsyncLocations"
params = {
    "template": "search",
    "level": "search",
    "radius": 5000,
    "lat": 39.0997,
    "lng": -94.5786,
    "limit": 2000,
}

# %%
r = requests.get(url, params=params)

# %%
data = r.json()
locations = data["markers"]

# %%
store_dicts = []
for location in locations:
    soup = BeautifulSoup(location["info"], "html.parser")
    store_url = soup.find("a", {"class": "store-info"}).attrs["href"]

    address = soup.find("div", {"class": "address"})
    text = address.find_all("div")[-2].text
    stusps = text.split(" ")[-2]
    if len(stusps) > 2:
        stusps = text.split(" ")[-3]

    point = Point(location["lng"], location["lat"])
    store_dict = {"url": store_url, "geometry": point, "STUSPS": stusps}
    store_dicts.append(store_dict)

# %%
store_gdf = gpd.GeoDataFrame(store_dicts, crs=4326)
store_gdf.to_file("data/stores.gpkg")

# %%
store_counts_df = store_gdf.groupby("STUSPS").size().reset_index(name="COUNT")

# %% [markdown]
# ## Combine With States

# %%
store_count_gdf = states_with_population_df.merge(
    store_counts_df, on="STUSPS", how="left"
)

# %%
store_count_gdf["per_100k"] = (
    store_count_gdf["COUNT"] / (store_count_gdf["POPULATION"] / 100_000)
).round(decimals=2)
store_count_gdf["per_1m"] = (
    store_count_gdf["COUNT"] / (store_count_gdf["POPULATION"] / 1_000_000)
).round(decimals=2)

# %%
store_count_gdf = store_count_gdf.to_crs(9311)
store_count_gdf.to_file(f"data/Spirit_Halloween_Locations_Per_State.gpkg")

# %%
store_count_gdf.sort_values("per_1m", ascending=False)
# Out:
#    STUSPS                                          NAME  POPULATION  \
# 34     NH                                 New Hampshire   1402199.0
# 2      OK                                      Oklahoma   4063882.0
# 24     WY                                       Wyoming    585067.0
# 43     DE                                      Delaware   1036423.0
# 21     CO                                      Colorado   5901339.0
# 35     AZ                                       Arizona   7473027.0
# 22     UT                                          Utah   3443222.0
# 50     OR                                        Oregon   4253653.0
# 19     PA                                  Pennsylvania  13017721.0
# 11     WA                                    Washington   7857320.0
# 39     NJ                                    New Jersey   9379642.0
# 27     AK                                        Alaska    736510.0
# 31     MT                                       Montana   1131302.0
# 12     NM                                    New Mexico   2121164.0
# 51     ND                                  North Dakota    789047.0
# 16     CA                                    California  39198693.0
# 28     NV                                        Nevada   3214363.0
# 48     OH                                          Ohio  11824034.0
# 3      VA                                      Virginia   8734685.0
# 9      FL                                       Florida  22904868.0
# 26     KS                                        Kansas   2951500.0
# 7      MA                                 Massachusetts   7066568.0
# 8      ID                                         Idaho   1971122.0
# 25     NY                                      New York  19737367.0
# 15     TX                                         Texas  30727890.0
# 55     CT                                   Connecticut   3643023.0
# 17     AL                                       Alabama   5117673.0
# 29     IL                                      Illinois  12642259.0
# 5      LA                                     Louisiana   4588071.0
# 6      MI                                      Michigan  10083356.0
# 4      WV                                 West Virginia   1770495.0
# 49     WI                                     Wisconsin   5930405.0
# 23     TN                                     Tennessee   7148304.0
# 53     IN                                       Indiana   6880131.0
# 46     RI                                  Rhode Island   1103429.0
# 41     ME                                         Maine   1399646.0
# 40     MD                                      Maryland   6217062.0
# 20     MO                                      Missouri   6208038.0
# 47     KY                                      Kentucky   4550595.0
# 54     MN                                     Minnesota   5753048.0
# 14     SD                                  South Dakota    918305.0
# 18     GA                                       Georgia  11064432.0
# 32     IA                                          Iowa   3218414.0
# 30     VT                                       Vermont    648708.0
# 1      NC                                North Carolina  10881189.0
# 33     SC                                South Carolina   5387830.0
# 42     HI                                        Hawaii   1441387.0
# 0      MS                                   Mississippi   2943172.0
# 52     AR                                      Arkansas   3069463.0
# 10     NE                                      Nebraska   1987864.0
# 13     PR                                   Puerto Rico   3203792.0
# 36     DC                          District of Columbia    687324.0
# 37     AS                                American Samoa         NaN
# 38     VI                  United States Virgin Islands         NaN
# 44     GU                                          Guam         NaN
# 45     MP  Commonwealth of the Northern Mariana Islands         NaN
#
#                                              geometry  COUNT  per_100k  per_1m
# 34  MULTIPOLYGON (((2326343.717 202530.281, 232642...   12.0      0.86    8.56
# 2   POLYGON ((-268912.756 -936547.904, -268600.891...   29.0      0.71    7.14
# 24  POLYGON ((-865730.986 59352.206, -864993.905 5...    4.0      0.68    6.84
# 43  MULTIPOLYGON (((2060773.554 -301785.14, 206090...    7.0      0.68    6.75
# 21  POLYGON ((-786602.67 -668516.216, -785169.939 ...   38.0      0.64    6.44
# 35  POLYGON ((-1389045.258 -1265605.408, -1388845....   48.0      0.64    6.42
# 22  POLYGON ((-1233486.447 -719056.636, -1233235.8...   22.0      0.64    6.39
# 50  MULTIPOLYGON (((-1781988.816 403834.726, -1781...   25.0      0.59    5.88
# 19  POLYGON ((1619177.315 -262060.235, 1618879.478...   75.0      0.58    5.76
# 11  MULTIPOLYGON (((-1634509.823 627551.89, -16343...   45.0      0.57    5.73
# 39  POLYGON ((2057761.964 -289308.055, 2057710.645...   52.0      0.55    5.54
# 27  MULTIPOLYGON (((-4288407.995 3426181.085, -428...    4.0      0.54    5.43
# 31  POLYGON ((-1172889.072 508069.731, -1172583.63...    6.0      0.53    5.30
# 12  POLYGON ((-862226.867 -1454497.308, -861997.92...   11.0      0.52    5.19
# 51  POLYGON ((-296121.109 437082.483, -296107.817 ...    4.0      0.51    5.07
# 16  MULTIPOLYGON (((-1717282.257 -1090154.595, -17...  196.0      0.50    5.00
# 28  POLYGON ((-1704625.157 -434251.605, -1704218.6...   16.0      0.50    4.98
# 48  MULTIPOLYGON (((1422967.707 -227158.235, 14230...   58.0      0.49    4.91
# 3   MULTIPOLYGON (((2098153.247 -490400.387, 20981...   42.0      0.48    4.81
# 9   MULTIPOLYGON (((1997726.172 -1929592.915, 1997...  109.0      0.48    4.76
# 26  POLYGON ((-174863.27 -553289.527, -163353.728 ...   14.0      0.47    4.74
# 7   MULTIPOLYGON (((2420778.194 34524.899, 2421697...   33.0      0.47    4.67
# 8   POLYGON ((-1357016.205 78008.02, -1356337.908 ...    9.0      0.46    4.57
# 25  MULTIPOLYGON (((2282948.092 -21624.723, 228289...   89.0      0.45    4.51
# 15  MULTIPOLYGON (((514197.103 -1677430.313, 51428...  138.0      0.45    4.49
# 55  MULTIPOLYGON (((2226858.014 -42564.968, 222677...   16.0      0.44    4.39
# 17  MULTIPOLYGON (((1149246.956 -1527666.558, 1149...   22.0      0.43    4.30
# 29  POLYGON ((720088.004 -498699.252, 720164.325 -...   53.0      0.42    4.19
# 5   MULTIPOLYGON (((1079322.442 -1609024.878, 1079...   19.0      0.41    4.14
# 6   MULTIPOLYGON (((1376542.504 -187676.574, 13766...   41.0      0.41    4.07
# 4   POLYGON ((1506482.53 -601393.056, 1506489.516 ...    7.0      0.40    3.95
# 49  MULTIPOLYGON (((1013687.487 121601.135, 101375...   23.0      0.39    3.88
# 23  POLYGON ((883547.508 -1059435.53, 883522.954 -...   27.0      0.38    3.78
# 53  POLYGON ((1041911.852 -714123.548, 1042168.307...   26.0      0.38    3.78
# 46  MULTIPOLYGON (((2326214.714 41825.849, 2326258...    4.0      0.36    3.63
# 41  MULTIPOLYGON (((2495259.496 476081.018, 249525...    5.0      0.36    3.57
# 40  MULTIPOLYGON (((2067172.995 -478871.787, 20670...   22.0      0.35    3.54
# 20  POLYGON ((357039.741 -482422.694, 357435.659 -...   22.0      0.35    3.54
# 47  MULTIPOLYGON (((946135.474 -881445.948, 946571...   16.0      0.35    3.52
# 54  MULTIPOLYGON (((772408.659 380232.264, 772444....   19.0      0.33    3.30
# 14  POLYGON ((-318857.556 7726.411, -318299.501 77...    3.0      0.33    3.27
# 18  MULTIPOLYGON (((1774018.899 -1324581.179, 1774...   36.0      0.33    3.25
# 32  POLYGON ((274418.778 -245971.628, 274712.711 -...   10.0      0.31    3.11
# 30  POLYGON ((2075870.027 238820.542, 2075640.482 ...    2.0      0.31    3.08
# 1   MULTIPOLYGON (((2154808.027 -692253.992, 21554...   33.0      0.30    3.03
# 33  MULTIPOLYGON (((1898434.953 -1099843.186, 1898...   15.0      0.28    2.78
# 42  MULTIPOLYGON (((-5544643.961 -943550.462, -554...    4.0      0.28    2.78
# 0   MULTIPOLYGON (((1109997.773 -1565578.875, 1111...    7.0      0.24    2.38
# 52  POLYGON ((482029.856 -928936.291, 482046.307 -...    7.0      0.23    2.28
# 10  POLYGON ((-339253.738 -417387.502, -339106.319...    4.0      0.20    2.01
# 13  MULTIPOLYGON (((3661734.646 -2226951.098, 3662...    NaN       NaN     NaN
# 36  POLYGON ((1950799.304 -402452.215, 1951231.574...    NaN       NaN     NaN
# 37  MULTIPOLYGON (((-7799029.401 -3753736.013, -77...    NaN       NaN     NaN
# 38  MULTIPOLYGON (((3738151.501 -2258200.246, 3738...    NaN       NaN     NaN
# 44  MULTIPOLYGON (((-8511256.588 4418401.614, -851...    NaN       NaN     NaN
# 45  MULTIPOLYGON (((-8256087.661 4425498.185, -825...    NaN       NaN     NaN
