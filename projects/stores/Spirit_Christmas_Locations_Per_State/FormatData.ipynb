# %%
import re
import json
import requests

# %%
import geopandas as gpd
import pandas as pd

# %%
from bs4 import BeautifulSoup
from shapely.geometry import Point
from tqdm.notebook import tqdm

# %% [markdown]
# ## Get State Data

# %%
file_path = "data/cb_2018_us_state_500k/cb_2018_us_state_500k.shp"
states_df = gpd.read_file(file_path)

# %%
states_df = states_df[["STUSPS", "NAME", "geometry"]]

# %% [markdown]
# ## Get Population data

# %%
state_populations = pd.read_excel(
    "data/NST-EST2024-POP.xlsx", sheet_name=None, engine="openpyxl"
)

# %%
state_populations_df = state_populations["NST-EST2024-POP"][
    [
        "table with row headers in column A and column headers in rows 3 through 4. (leading dots indicate sub-parts)",
        "Unnamed: 5",
    ]
]
state_populations_df = state_populations_df.rename(
    columns={
        "table with row headers in column A and column headers in rows 3 through 4. (leading dots indicate sub-parts)": "NAME",
        "Unnamed: 5": "POPULATION",
    }
)
state_populations_df["NAME"] = state_populations_df["NAME"].str[1:]

# %%
states_with_population_df = states_df.merge(state_populations_df, on="NAME", how="left")
states_with_population_df = states_with_population_df[
    ["STUSPS", "NAME", "POPULATION", "geometry"]
]

# %% [markdown]
# ## Get Store Data

# %%
def get_urls(url: str) -> list:
    r = requests.get(url)
    soup = BeautifulSoup(r.text, "html.parser")
    divs = soup.find_all("div", {"class": "map-list-item is-single"})
    return [div.find("a").attrs["href"] for div in divs]

# %%
def get_coords(url: str) -> Point:
    r = requests.get(url)
    soup = BeautifulSoup(r.text, "html.parser")
    gmap = soup.find("div", {"id": "gmap"})
    script = gmap.find("script", {"type": "text/javascript"})
    match = re.search(r"=\s*({.*});", script.text, flags=re.S)
    if match:
        js_text = match.group(1)
        lat_match = re.search(r'"centerLat"\s*:\s*([0-9\.\-]+)', js_text)
        lng_match = re.search(r'"centerLng"\s*:\s*([0-9\.\-]+)', js_text)
        if lat_match and lng_match:
            lat = float(lat_match.group(1))
            lng = float(lng_match.group(1))
        else:
            print(url)
    return Point(lng, lat)

# %%
url = "https://stores.spirithalloween.com/christmas/"
state_urls = get_urls(url)

# %%
store_urls_usa = []
for state_url in tqdm(state_urls, desc="Parsing States"):
    store_urls = get_urls(state_url)
    store_urls_usa.extend(store_urls)
# Out:
# Parsing States:   0%|          | 0/13 [00:00<?, ?it/s]

# %%
store_dicts = []
for store_url in tqdm(store_urls_usa, desc="Parsing Stores"):
    point = get_coords(store_url)
    STUSPS = store_url.split("/")[-3].upper()
    store_dict = {"STUSPS": STUSPS, "url": store_url, "geometry": point}
    store_dicts.append(store_dict)
# Out:
# Parsing Stores:   0%|          | 0/30 [00:00<?, ?it/s]

# %%
store_gdf = gpd.GeoDataFrame(store_dicts, crs=4326)
store_gdf = store_gdf.to_crs(26917)
store_gdf.to_file("data/stores.gpkg")

# %%
store_counts_df = store_gdf.groupby("STUSPS").size().reset_index(name="COUNT")

# %% [markdown]
# ## Combine With States

# %%
store_count_gdf = states_with_population_df.merge(
    store_counts_df, on="STUSPS", how="left"
)

# %%
store_count_gdf["per_100k"] = (
    store_count_gdf["COUNT"] / (store_count_gdf["POPULATION"] / 100_000)
).round(decimals=2)
store_count_gdf["per_1m"] = (
    store_count_gdf["COUNT"] / (store_count_gdf["POPULATION"] / 1_000_000)
).round(decimals=1)

# %%
store_count_gdf = store_count_gdf.fillna(0)

# %%
store_count_gdf = store_count_gdf.to_crs(26917)
store_count_gdf.to_file(f"data/Spirit_Christmas_Locations_Per_State.gpkg")

# %%
store_count_gdf.sort_values("per_1m", ascending=False)
# Out:
#    STUSPS                                          NAME  POPULATION  \
# 43     DE                                      Delaware   1036423.0
# 34     NH                                 New Hampshire   1402199.0
# 39     NJ                                    New Jersey   9379642.0
# 55     CT                                   Connecticut   3643023.0
# 7      MA                                 Massachusetts   7066568.0
# 19     PA                                  Pennsylvania  13017721.0
# 53     IN                                       Indiana   6880131.0
# 6      MI                                      Michigan  10083356.0
# 29     IL                                      Illinois  12642259.0
# 25     NY                                      New York  19737367.0
# 40     MD                                      Maryland   6217062.0
# 48     OH                                          Ohio  11824034.0
# 47     KY                                      Kentucky   4550595.0
# 13     PR                                   Puerto Rico   3203792.0
# 12     NM                                    New Mexico   2121164.0
# 9      FL                                       Florida  22904868.0
# 4      WV                                 West Virginia   1770495.0
# 8      ID                                         Idaho   1971122.0
# 10     NE                                      Nebraska   1987864.0
# 0      MS                                   Mississippi   2943172.0
# 3      VA                                      Virginia   8734685.0
# 2      OK                                      Oklahoma   4063882.0
# 5      LA                                     Louisiana   4588071.0
# 1      NC                                North Carolina  10881189.0
# 23     TN                                     Tennessee   7148304.0
# 22     UT                                          Utah   3443222.0
# 21     CO                                      Colorado   5901339.0
# 20     MO                                      Missouri   6208038.0
# 18     GA                                       Georgia  11064432.0
# 17     AL                                       Alabama   5117673.0
# 16     CA                                    California  39198693.0
# 15     TX                                         Texas  30727890.0
# 11     WA                                    Washington   7857320.0
# 14     SD                                  South Dakota    918305.0
# 31     MT                                       Montana   1131302.0
# 30     VT                                       Vermont    648708.0
# 27     AK                                        Alaska    736510.0
# 28     NV                                        Nevada   3214363.0
# 26     KS                                        Kansas   2951500.0
# 24     WY                                       Wyoming    585067.0
# 38     VI                  United States Virgin Islands         0.0
# 37     AS                                American Samoa         0.0
# 36     DC                          District of Columbia    687324.0
# 35     AZ                                       Arizona   7473027.0
# 32     IA                                          Iowa   3218414.0
# 33     SC                                South Carolina   5387830.0
# 42     HI                                        Hawaii   1441387.0
# 41     ME                                         Maine   1399646.0
# 46     RI                                  Rhode Island   1103429.0
# 45     MP  Commonwealth of the Northern Mariana Islands         0.0
# 44     GU                                          Guam         0.0
# 49     WI                                     Wisconsin   5930405.0
# 51     ND                                  North Dakota    789047.0
# 50     OR                                        Oregon   4253653.0
# 52     AR                                      Arkansas   3069463.0
# 54     MN                                     Minnesota   5753048.0
#
#                                              geometry  COUNT  per_100k  per_1m
# 43  MULTIPOLYGON (((967283.744 4388036.33, 967572....    1.0      0.10     1.0
# 34  MULTIPOLYGON (((1346926.116 4810894.355, 13470...    1.0      0.07     0.7
# 39  POLYGON ((967068.404 4400755.516, 967033.756 4...    6.0      0.06     0.6
# 55  MULTIPOLYGON (((1190642.294 4598514.422, 11907...    2.0      0.05     0.5
# 7   MULTIPOLYGON (((1402184.105 4626749.517, 14031...    2.0      0.03     0.3
# 19  POLYGON ((540434.878 4528506.569, 540493.467 4...    4.0      0.03     0.3
# 53  POLYGON ((-124368.376 4218994.073, -124062.676...    2.0      0.03     0.3
# 6   MULTIPOLYGON (((318593.539 4656026.917, 318733...    2.0      0.02     0.2
# 29  POLYGON ((-395840.263 4501208.149, -395574.947...    3.0      0.02     0.2
# 25  MULTIPOLYGON (((1251358.969 4605412.599, 12514...    3.0      0.02     0.2
# 40  MULTIPOLYGON (((934792.609 4215937.806, 934789...    1.0      0.02     0.2
# 48  MULTIPOLYGON (((355361.004 4607194.262, 355511...    2.0      0.02     0.2
# 47  MULTIPOLYGON (((-253286.394 4075558.551, -2525...    1.0      0.02     0.2
# 13  MULTIPOLYGON (((2182720.663 2099867.819, 21830...    0.0      0.00     0.0
# 12  POLYGON ((-2211689.965 3847649.502, -2211023.2...    0.0      0.00     0.0
# 9   MULTIPOLYGON (((582766.836 2823344.674, 583000...    0.0      0.00     0.0
# 4   POLYGON ((356058.772 4225851.909, 356077.315 4...    0.0      0.00     0.0
# 8   POLYGON ((-2377995.58 5598964.117, -2377207.97...    0.0      0.00     0.0
# 10  POLYGON ((-1439701.517 4822252.896, -1438900.1...    0.0      0.00     0.0
# 0   MULTIPOLYGON (((-223102.156 3366548.377, -2220...    0.0      0.00     0.0
# 3   MULTIPOLYGON (((962963.858 4197593.55, 963032....    0.0      0.00     0.0
# 2   POLYGON ((-1483273.842 4275657.465, -1481165.8...    0.0      0.00     0.0
# 5   MULTIPOLYGON (((-261084.532 3329566.297, -2608...    0.0      0.00     0.0
# 1   MULTIPOLYGON (((975855.342 3989705.067, 976603...    0.0      0.00     0.0
# 23  POLYGON ((-350816.957 3913380.589, -350721.217...    0.0      0.00     0.0
# 22  POLYGON ((-2453081.082 4715432.11, -2452491.40...    0.0      0.00     0.0
# 21  POLYGON ((-1962346.56 4666165.791, -1957735.33...    0.0      0.00     0.0
# 20  POLYGON ((-752404.074 4598244.343, -751879.66 ...    0.0      0.00     0.0
# 18  MULTIPOLYGON (((473413.683 3463761.703, 473626...    0.0      0.00     0.0
# 17  MULTIPOLYGON (((-177631.102 3396206.867, -1773...    0.0      0.00     0.0
# 16  MULTIPOLYGON (((-3083098.089 4415286.983, -308...    0.0      0.00     0.0
# 15  MULTIPOLYGON (((-833151.905 3368857.501, -8330...    0.0      0.00     0.0
# 11  MULTIPOLYGON (((-2511340.698 6267940.086, -251...    0.0      0.00     0.0
# 14  POLYGON ((-1316222.753 5248298.931, -1315659.4...    0.0      0.00     0.0
# 31  POLYGON ((-2059351.37 5994879.545, -2058607.37...    0.0      0.00     0.0
# 30  POLYGON ((1105896.201 4904752.896, 1106167.589...    0.0      0.00     0.0
# 27  MULTIPOLYGON (((-4001721.404 10818674.592, -40...    0.0      0.00     0.0
# 28  POLYGON ((-2902078.609 5143375.983, -2901160.2...    0.0      0.00     0.0
# 26  POLYGON ((-1303280.489 4646443.274, -1291638.8...    0.0      0.00     0.0
# 24  POLYGON ((-1864060.392 5442669.356, -1863321.1...    0.0      0.00     0.0
# 38  MULTIPOLYGON (((2254823.019 2045001.681, 22549...    0.0      0.00     0.0
# 37  MULTIPOLYGON (((-12381124.774 -8837534.794, -1...    0.0      0.00     0.0
# 36  POLYGON ((836361.697 4316654.323, 836961.296 4...    0.0      0.00     0.0
# 35  POLYGON ((-2750193.984 4152071.747, -2749954.4...    0.0      0.00     0.0
# 32  POLYGON ((-781302.078 4851856.616, -780905.707...    0.0      0.00     0.0
# 33  MULTIPOLYGON (((639356.154 3654501.492, 639432...    0.0      0.00     0.0
# 42  MULTIPOLYGON (((-9210200.937 6064233.345, -920...    0.0      0.00     0.0
# 41  MULTIPOLYGON (((1582099.215 5034621.77, 158216...    0.0      0.00     0.0
# 46  MULTIPOLYGON (((1309216.446 4656235.085, 13093...    0.0      0.00     0.0
# 45  MULTIPOLYGON (((-5080164.357 17463371.983, -50...    0.0      0.00     0.0
# 44  MULTIPOLYGON (((-4985565.341 17933718.311, -49...    0.0      0.00     0.0
# 49  MULTIPOLYGON (((33485.268 5039725.192, 33630.7...    0.0      0.00     0.0
# 51  POLYGON ((-1183149.69 5673887.565, -1183079.34...    0.0      0.00     0.0
# 50  MULTIPOLYGON (((-2741826.434 6078721.249, -274...    0.0      0.00     0.0
# 52  POLYGON ((-722882.841 4126736.878, -722866.223...    0.0      0.00     0.0
# 54  MULTIPOLYGON (((-141087.612 5348428.419, -1410...    0.0      0.00     0.0
