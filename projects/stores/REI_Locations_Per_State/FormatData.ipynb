# %%
import json

# %%
from urllib.parse import unquote

# %%
from bs4 import BeautifulSoup
from curl_cffi import requests
import geopandas as gpd
import pandas as pd
from shapely.geometry import Point

# %% [markdown]
# ## Get State Data

# %%
file_path = "data/cb_2018_us_state_500k/cb_2018_us_state_500k.shp"
states_df = gpd.read_file(file_path)

# %%
states_df = states_df[["STUSPS", "NAME", "geometry"]]

# %% [markdown]
# ## Get Population data

# %%
state_populations = pd.read_excel(
    "data/NST-EST2024-POP.xlsx", sheet_name=None, engine="openpyxl"
)

# %%
state_populations_df = state_populations["NST-EST2024-POP"][
    [
        "table with row headers in column A and column headers in rows 3 through 4. (leading dots indicate sub-parts)",
        "Unnamed: 5",
    ]
]
state_populations_df = state_populations_df.rename(
    columns={
        "table with row headers in column A and column headers in rows 3 through 4. (leading dots indicate sub-parts)": "NAME",
        "Unnamed: 5": "POPULATION",
    }
)
state_populations_df["NAME"] = state_populations_df["NAME"].str[1:]

# %%
states_with_population_df = states_df.merge(state_populations_df, on="NAME", how="left")
states_with_population_df = states_with_population_df[
    ["STUSPS", "NAME", "POPULATION", "geometry"]
]

# %% [markdown]
# ## Get REI Data

# %%
url = "https://www.rei.com/stores/map"
headers = {
    "accept": "text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.7",
    "accept-language": "en-US,en;q=0.9,ru;q=0.8,el;q=0.7",
    "cache-control": "max-age=0",
    "priority": "u=0, i",
    "sec-ch-ua": '"Chromium";v="140", "Not=A?Brand";v="24", "Google Chrome";v="140"',
    "sec-ch-ua-mobile": "?0",
    "sec-ch-ua-platform": '"Windows"',
    "sec-fetch-dest": "document",
    "sec-fetch-mode": "navigate",
    "sec-fetch-site": "cross-site",
    "sec-fetch-user": "?1",
    "upgrade-insecure-requests": "1",
    "Referer": "https://www.google.com/",
}

raw_cookie = """"""  # Add your cookie from the source in the README.md you need to open dev tools on a browser and copy your cookie here
cookies = dict(item.strip().split("=", 1) for item in raw_cookie.split("; "))

resp = requests.get(
    "https://www.rei.com/stores/map",
    headers=headers,
    cookies=cookies,
    impersonate="chrome110",
)

# %%
soup = BeautifulSoup(resp.text, "html.parser")
script = soup.find("script", {"type": "application/json", "id": "modelData"})

# %%
resp_dict = json.loads(script.text)
stores = resp_dict["pageData"]["allStores"]["storeLocatorDataQueryModelList"]

# %%
store_dicts = []
for store in stores:
    store_dict = store["storeDataModel"]
    if store_dict["countryCode"] == "US":
        store_dicts.append(
            {
                "ID": store_dict["storeNumber"],
                "geometry": Point(store_dict["longitude"], store_dict["latitude"]),
                "STUSPS": store_dict["stateCode"],
                "URL": store_dict["directionLink"],
            }
        )

# %%
store_gdf = gpd.GeoDataFrame(store_dicts, crs=4326)

# %%
store_gdf = store_gdf.to_crs(9311)
store_gdf.to_file("data/stores.gpkg")

# %%
stores_count_df = store_gdf.groupby("STUSPS").size().reset_index(name="COUNT")

# %% [markdown]
# ## Combine With States

# %%
stores_count_gdf = states_with_population_df.merge(
    stores_count_df, on="STUSPS", how="left"
)

# %%
stores_count_gdf = stores_count_gdf.fillna(0)

# %%
stores_count_gdf["per_100k"] = (
    stores_count_gdf["COUNT"] / (stores_count_gdf["POPULATION"] / 100_000)
).round(decimals=1)
stores_count_gdf["per_1m"] = (
    stores_count_gdf["COUNT"] / (stores_count_gdf["POPULATION"] / 1_000_000)
).round(decimals=1)

# %%
stores_count_gdf = stores_count_gdf.fillna(0)

# %%
stores_count_gdf = stores_count_gdf.to_crs(9311)
stores_count_gdf.to_file(f"data/REI_Locations_Per_Statae.gpkg")

# %%
stores_count_gdf.sort_values("per_1m", ascending=False)
# Out:
#    STUSPS                                          NAME  POPULATION  \
# 31     MT                                       Montana   1131302.0
# 27     AK                                        Alaska    736510.0
# 50     OR                                        Oregon   4253653.0
# 21     CO                                      Colorado   5901339.0
# 24     WY                                       Wyoming    585067.0
# 36     DC                          District of Columbia    687324.0
# 30     VT                                       Vermont    648708.0
# 11     WA                                    Washington   7857320.0
# 34     NH                                 New Hampshire   1402199.0
# 43     DE                                      Delaware   1036423.0
# 12     NM                                    New Mexico   2121164.0
# 22     UT                                          Utah   3443222.0
# 46     RI                                  Rhode Island   1103429.0
# 28     NV                                        Nevada   3214363.0
# 35     AZ                                       Arizona   7473027.0
# 55     CT                                   Connecticut   3643023.0
# 16     CA                                    California  39198693.0
# 3      VA                                      Virginia   8734685.0
# 41     ME                                         Maine   1399646.0
# 26     KS                                        Kansas   2951500.0
# 23     TN                                     Tennessee   7148304.0
# 33     SC                                South Carolina   5387830.0
# 7      MA                                 Massachusetts   7066568.0
# 1      NC                                North Carolina  10881189.0
# 49     WI                                     Wisconsin   5930405.0
# 40     MD                                      Maryland   6217062.0
# 18     GA                                       Georgia  11064432.0
# 2      OK                                      Oklahoma   4063882.0
# 8      ID                                         Idaho   1971122.0
# 10     NE                                      Nebraska   1987864.0
# 54     MN                                     Minnesota   5753048.0
# 48     OH                                          Ohio  11824034.0
# 6      MI                                      Michigan  10083356.0
# 15     TX                                         Texas  30727890.0
# 17     AL                                       Alabama   5117673.0
# 29     IL                                      Illinois  12642259.0
# 25     NY                                      New York  19737367.0
# 39     NJ                                    New Jersey   9379642.0
# 20     MO                                      Missouri   6208038.0
# 19     PA                                  Pennsylvania  13017721.0
# 32     IA                                          Iowa   3218414.0
# 9      FL                                       Florida  22904868.0
# 47     KY                                      Kentucky   4550595.0
# 53     IN                                       Indiana   6880131.0
# 0      MS                                   Mississippi   2943172.0
# 14     SD                                  South Dakota    918305.0
# 5      LA                                     Louisiana   4588071.0
# 4      WV                                 West Virginia   1770495.0
# 13     PR                                   Puerto Rico   3203792.0
# 37     AS                                American Samoa         0.0
# 38     VI                  United States Virgin Islands         0.0
# 42     HI                                        Hawaii   1441387.0
# 44     GU                                          Guam         0.0
# 45     MP  Commonwealth of the Northern Mariana Islands         0.0
# 51     ND                                  North Dakota    789047.0
# 52     AR                                      Arkansas   3069463.0
#
#                                              geometry  COUNT  per_100k  per_1m
# 31  POLYGON ((-1172889.072 508069.731, -1172583.63...    4.0       0.4     3.5
# 27  MULTIPOLYGON (((-4288407.995 3426181.085, -428...    2.0       0.3     2.7
# 50  MULTIPOLYGON (((-1781988.816 403834.726, -1781...    9.0       0.2     2.1
# 21  POLYGON ((-786602.67 -668516.216, -785169.939 ...   11.0       0.2     1.9
# 24  POLYGON ((-865730.986 59352.206, -864993.905 5...    1.0       0.2     1.7
# 36  POLYGON ((1950799.304 -402452.215, 1951231.574...    1.0       0.1     1.5
# 30  POLYGON ((2075870.027 238820.542, 2075640.482 ...    1.0       0.2     1.5
# 11  MULTIPOLYGON (((-1634509.823 627551.89, -16343...   11.0       0.1     1.4
# 34  MULTIPOLYGON (((2326343.717 202530.281, 232642...    2.0       0.1     1.4
# 43  MULTIPOLYGON (((2060773.554 -301785.14, 206090...    1.0       0.1     1.0
# 12  POLYGON ((-862226.867 -1454497.308, -861997.92...    2.0       0.1     0.9
# 22  POLYGON ((-1233486.447 -719056.636, -1233235.8...    3.0       0.1     0.9
# 46  MULTIPOLYGON (((2326214.714 41825.849, 2326258...    1.0       0.1     0.9
# 28  POLYGON ((-1704625.157 -434251.605, -1704218.6...    3.0       0.1     0.9
# 35  POLYGON ((-1389045.258 -1265605.408, -1388845....    6.0       0.1     0.8
# 55  MULTIPOLYGON (((2226858.014 -42564.968, 222677...    3.0       0.1     0.8
# 16  MULTIPOLYGON (((-1717282.257 -1090154.595, -17...   33.0       0.1     0.8
# 3   MULTIPOLYGON (((2098153.247 -490400.387, 20981...    6.0       0.1     0.7
# 41  MULTIPOLYGON (((2495259.496 476081.018, 249525...    1.0       0.1     0.7
# 26  POLYGON ((-174863.27 -553289.527, -163353.728 ...    2.0       0.1     0.7
# 23  POLYGON ((883547.508 -1059435.53, 883522.954 -...    5.0       0.1     0.7
# 33  MULTIPOLYGON (((1898434.953 -1099843.186, 1898...    3.0       0.1     0.6
# 7   MULTIPOLYGON (((2420778.194 34524.899, 2421697...    4.0       0.1     0.6
# 1   MULTIPOLYGON (((2154808.027 -692253.992, 21554...    7.0       0.1     0.6
# 49  MULTIPOLYGON (((1013687.487 121601.135, 101375...    3.0       0.1     0.5
# 40  MULTIPOLYGON (((2067172.995 -478871.787, 20670...    3.0       0.0     0.5
# 18  MULTIPOLYGON (((1774018.899 -1324581.179, 1774...    5.0       0.0     0.5
# 2   POLYGON ((-268912.756 -936547.904, -268600.891...    2.0       0.0     0.5
# 8   POLYGON ((-1357016.205 78008.02, -1356337.908 ...    1.0       0.1     0.5
# 10  POLYGON ((-339253.738 -417387.502, -339106.319...    1.0       0.1     0.5
# 54  MULTIPOLYGON (((772408.659 380232.264, 772444....    3.0       0.1     0.5
# 48  MULTIPOLYGON (((1422967.707 -227158.235, 14230...    5.0       0.0     0.4
# 6   MULTIPOLYGON (((1376542.504 -187676.574, 13766...    4.0       0.0     0.4
# 15  MULTIPOLYGON (((514197.103 -1677430.313, 51428...   11.0       0.0     0.4
# 17  MULTIPOLYGON (((1149246.956 -1527666.558, 1149...    2.0       0.0     0.4
# 29  POLYGON ((720088.004 -498699.252, 720164.325 -...    5.0       0.0     0.4
# 25  MULTIPOLYGON (((2282948.092 -21624.723, 228289...    7.0       0.0     0.4
# 39  POLYGON ((2057761.964 -289308.055, 2057710.645...    4.0       0.0     0.4
# 20  POLYGON ((357039.741 -482422.694, 357435.659 -...    2.0       0.0     0.3
# 19  POLYGON ((1619177.315 -262060.235, 1618879.478...    4.0       0.0     0.3
# 32  POLYGON ((274418.778 -245971.628, 274712.711 -...    1.0       0.0     0.3
# 9   MULTIPOLYGON (((1997726.172 -1929592.915, 1997...    8.0       0.0     0.3
# 47  MULTIPOLYGON (((946135.474 -881445.948, 946571...    1.0       0.0     0.2
# 53  POLYGON ((1041911.852 -714123.548, 1042168.307...    1.0       0.0     0.1
# 0   MULTIPOLYGON (((1109997.773 -1565578.875, 1111...    0.0       0.0     0.0
# 14  POLYGON ((-318857.556 7726.411, -318299.501 77...    0.0       0.0     0.0
# 5   MULTIPOLYGON (((1079322.442 -1609024.878, 1079...    0.0       0.0     0.0
# 4   POLYGON ((1506482.53 -601393.056, 1506489.516 ...    0.0       0.0     0.0
# 13  MULTIPOLYGON (((3661734.646 -2226951.098, 3662...    0.0       0.0     0.0
# 37  MULTIPOLYGON (((-7799029.401 -3753736.013, -77...    0.0       0.0     0.0
# 38  MULTIPOLYGON (((3738151.501 -2258200.246, 3738...    0.0       0.0     0.0
# 42  MULTIPOLYGON (((-5544643.961 -943550.462, -554...    0.0       0.0     0.0
# 44  MULTIPOLYGON (((-8511256.588 4418401.614, -851...    0.0       0.0     0.0
# 45  MULTIPOLYGON (((-8256087.661 4425498.185, -825...    0.0       0.0     0.0
# 51  POLYGON ((-296121.109 437082.483, -296107.817 ...    0.0       0.0     0.0
# 52  POLYGON ((482029.856 -928936.291, 482046.307 -...    0.0       0.0     0.0
