# %%
import requests
from functools import reduce

# %%
import numpy as np
import geopandas as gpd
import pandas as pd

# %%
from tqdm.notebook import tqdm

# %% [markdown]
# ## Open State data

# %%
file_path = "data/cb_2024_us_county_500k/cb_2024_us_county_500k.shp"
counties_gdf = gpd.read_file(file_path)

# %% [markdown]
# ## Get Ethnic Data

# %%
r = requests.get("https://api.census.gov/data/2023/acs/acs5/groups/B04006.json")
columns_obj = r.json()

# %%
columns = []
rename_vars = {}
variables = columns_obj["variables"]
for name, variable in list(variables.items()):
    v_split = variable["label"].split("!!")

    if v_split[0] == "Estimate":
        label = v_split[-1]
        rename_vars[name] = label

    if name.endswith("EA") or name.endswith("MA") or name == "GEO_ID":
        continue
    else:
        columns.append(name)

# %%
dfs = []
for i in tqdm(range(0, len(columns), 49), desc="Requesting data in batches"):
    columns_with_geoid = columns[i : i + 49]
    columns_with_geoid.append("GEO_ID")
    columns_formatted = ",".join(columns_with_geoid)
    url = f"https://api.census.gov/data/2023/acs/acs5?get={columns_formatted}&for=county:*"
    response = requests.get(url)
    data = response.json()
    df = pd.DataFrame(data[1:], columns=data[0])

    df = df.drop(columns=["state", "county"], errors="ignore")
    dfs.append(df)
# Out:
# Requesting data in batches:   0%|          | 0/5 [00:00<?, ?it/s]

# %%
df = reduce(lambda left, right: pd.merge(left, right, on="GEO_ID", how="inner"), dfs)

# %%
df = df.replace(np.nan, 0)

# %%
estimate_cols = [col for col in df.columns if col.endswith("E") and col != "NAME"]

# %%
formtted_df = df[["GEO_ID", *estimate_cols]]
formtted_df = formtted_df.drop(columns=["NAME"], errors="ignore")

# %%
formtted_df[estimate_cols] = formtted_df[estimate_cols].astype(int)

# %%
formtted_df["largest_ancestry"] = formtted_df[
    [
        col
        for col in estimate_cols
        if col not in ["B04006_001E", "B04006_108E", "B04006_109E"]
    ]
].idxmax(axis=1)

# %%
formtted_df["largest_ancestry"]
# Out:
# 0       B04006_036E
# 1       B04006_005E
# 2       B04006_005E
# 3       B04006_005E
# 4       B04006_036E
#            ...
# 3217    B04006_005E
# 3218    B04006_005E
# 3219    B04006_005E
# 3220    B04006_005E
# 3221    B04006_005E
# Name: largest_ancestry, Length: 3222, dtype: object

# %%
def check_majority(row) -> str:
    geo_id = row["GEO_ID"]
    largest_ancestry = row["largest_ancestry"]
    total_pop = row["B04006_001E"]
    val = row[largest_ancestry]

    if not val:
        return None

    if val / total_pop > 0.50:
        return variables[largest_ancestry]["label"].split("!!")[-1]
    else:
        return None

# %%
formtted_df["largest_ancestry_majority"] = formtted_df.apply(
    lambda row: check_majority(row), axis=1
)

# %%
formtted_df[~formtted_df["largest_ancestry_majority"].isna()]
# Out:
#               GEO_ID  B04006_009E  B04006_008E  B04006_007E  B04006_001E  \
# 603   0500000US17013            0            0            0         4406
# 804   0500000US19027            0            0            0        20677
# 809   0500000US19037            0            0            0        11868
# 955   0500000US20131            0            0            0        10213
# 972   0500000US20165            0            0            0         2957
# 987   0500000US20195            0            0            0         2778
# 1323  0500000US27015            0            0            0        25826
# 1387  0500000US27143            0            0            0        14933
# 1560  0500000US29151            0            0            0        13379
# 1669  0500000US31027            0            0            0         8344
# 2014            0            0            0          876          259
# 2015            0            0            0          394          100
# 2017            0            0            0          413          176
# 2024            0            0            0          322          111
# 2033            0            0            0          330           71
# 2043            0            0            0          886          159
# 2098            0            0            0        10622         3344
# 2113            0            0            0         8277         3173
# 2373            0            0            0          220          107
# 2385            0            0            0          706          211
# 2387            0            0            0          307          105
# 2396            0            0            0         1397          542
# 2397            0            0            0          177          132
# 2407            0            0            0          414          133
# 2427            0            0            0          936          691
# 2835            0            0            0         4171         1479
# 2847            0            0            0         3094         1031
# 3062            0            0            0        16336        10082
# 3115            0            0            0        27215        11169
#
#       B04006_102E  B04006_101E  B04006_100E  largest_ancestry  \
# 603             0            0            0       B04006_042E
# 804             0            0            0       B04006_042E
# 809             0            0            0       B04006_042E
# 955             0            0            4       B04006_042E
# 972             0            0            0       B04006_042E
# 987             0            0            0       B04006_042E
# 1323            0            0            0       B04006_042E
# 1387            0            0            0       B04006_042E
# 1560            0            0            0       B04006_042E
# 1669            0            0            0       B04006_042E
# 1675           56            0            0       B04006_042E
# 1725            0            0            0       B04006_042E
# 1740            0            0            0       B04006_042E
# 2006            0            0            0       B04006_042E
# 2010            0            0            0       B04006_042E
# 2012            3            0            0       B04006_042E
# 2013            0            0            0       B04006_042E
# 2014            0            0            0       B04006_042E
# 2015            0            0            0       B04006_042E
# 2017            0            0            0       B04006_042E
# 2024            0            0            0       B04006_042E
# 2033            0            0            0       B04006_042E
# 2043            0            0            0       B04006_042E
# 2098          118            0            0       B04006_042E
# 2113            0            8            0       B04006_042E
# 2373            0            0            0       B04006_042E
# 2385            0            0            0       B04006_042E
# 2387            0            0            0       B04006_042E
# 2396            5            0            0       B04006_042E
# 2397            0            0            0       B04006_042E
# 2407            0            0            0       B04006_042E
# 2427            0            0            0       B04006_042E
# 2835            0            1            0       B04006_005E
# 2847           17            0            0       B04006_005E
# 3062           39           27            0       B04006_042E
# 3115          138            0            0       B04006_042E
#
#       largest_ancestry_majority
# 603                      German
# 804                      German
# 809                      German
# 955                      German
# 972                      German
# 987                      German
# 1323                     German
# 1387                     German
# 1560                     German
# 1669                     German
# 1675                     German
# 1725                     German
# 1740                     German
# 2006                     German
# 2010                     German
# 2012                     German
# 2013                     German
# 2014                     German
# 2015                     German
# 2017                     German
# 2024                     German
# 2033                     German
# 2043                     German
# 2098                     German
# 2113                     German
# 2373                     German
# 2385                     German
# 2387                     German
# 2396                     German
# 2397                     German
# 2407                     German
# 2427                     German
# 2835                   American
# 2847                   American
# 3062                     German
# 3115                     German
#
# [36 rows x 112 columns]

# %%
rename_vars["GEO_ID"] = "GEOIDFQ"
formtted_df = formtted_df.rename(columns=rename_vars)

# %%
formtted_df.groupby("largest_ancestry_majority").size().reset_index(
    name="COUNT"
).sort_values("COUNT", ascending=False)
# Out:
#   largest_ancestry_majority  COUNT
# 1                    German     34
# 0                  American      2

# %% [markdown]
# ## Merge Data

# %%
gdf = counties_gdf.merge(formtted_df, on="GEOIDFQ", how="inner")

# %%
gdf = gdf.to_crs(9311)
gdf.to_file("data/Largest_White_Ancestry_Majority_Only_Per_County.gpkg")
